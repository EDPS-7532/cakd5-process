# %% [markdown]
# # LSTM으로 텍스트 생성하기
#
# ## 글자 수준의 LSTM 텍스트 생성 모델 구현
#
# 이런 아이디어를 케라스로 구현해 보죠. 먼저 언어 모델을 학습하기 위해 많은 텍스트 데이터가 필요합니다. 위키피디아나 반지의 제왕처럼 아주 큰 텍스트 파일이나 텍스트 파일의 묶음을 사용할 수 있습니다. 이 예에서는 19세기 후반 독일의 철학자 니체의 글을 사용하겠습니다(영어로 번역된 글입니다). 학습할 언어 모델은 일반적인 영어 모델이 아니라 니체의 문체와 특정 주제를 따르는 모델일 것입니다.

# %%
from tensorflow.keras import utils
import numpy as np

path = utils.get_file(
    'nietzche.txt',
    origin = 'https://s3.amazonaws.com/text-datasets/nietzsche.txt')

text = open(path).read().lower()
print('말뭉치 크기:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# 614400/600901 [==============================] - 0s 0us/step
# 말뭉치 크기: 600893

# %%
text[:500]
# Out:
# 'preface\n\n\nsupposing that truth is a woman--what then? is there not ground\nfor suspecting that all philosophers, in so far as they have been\ndogmatists, have failed to understand women--that the terrible\nseriousness and clumsy importunity with which they have usually paid\ntheir addresses to truth, have been unskilled and unseemly methods for\nwinning a woman? certainly she has never allowed herself to be won; and\nat present every kind of dogma stands with sad and discouraged mien--if,\nindeed, it s'

# %% [markdown]
# ## 60개 글자로 된 시퀀스를 추출

# %%
maxlen = 60 # 60개 글자로 된 시퀀스 추출
step = 3 # 세 글자씩 건너뛰면서 새로운 시퀀스를 샘플링

sentences = [] # 추출한 시퀀스를 담을 리스트
next_chars = [] # 타깃(시퀀스 다음 글자)을 담을 리스트

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i:i+maxlen])
    next_chars.append(text[i+maxlen])
print('시퀀스 개수:', len(sentences))

chars = sorted(list(set(text))) # 말뭉치에서 고유한 글자를 담은 리스트
print('고유한 글자:', len(chars))

char_indices = dict((char, char.index(char)) for char in chars) # chars 리스트에 있는 글자와 글자의 인덱스를 매핑한 딕셔너리
# Out:
# 시퀀스 개수: 200278
# 고유한 글자: 57

# %%
maxlen = 60

# 세글자씩 건너 뛰면서 새로운 시퀀스를 생성
step = 3

sentences = [] # 추출한 시퀀스를 담을 리스트
next_chars = [] # 타깃(시퀀스 다음글자)을 담을 리스트

for i in range(0, len(text) - maxlen, step):
  sentences.append(text[i: i+maxlen])
  next_chars.append(text[i + maxlen])
  print('시퀀스 개수:', len(sentences))
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 시퀀스 개수: 195279
# 시퀀스 개수: 195280
# 시퀀스 개수: 195281
# 시퀀스 개수: 195282
# 시퀀스 개수: 195283
# 시퀀스 개수: 195284
# 시퀀스 개수: 195285
# 시퀀스 개수: 195286
# 시퀀스 개수: 195287
# 시퀀스 개수: 195288
# 시퀀스 개수: 195289
# 시퀀스 개수: 195290
# 시퀀스 개수: 195291
# 시퀀스 개수: 195292
# 시퀀스 개수: 195293
# 시퀀스 개수: 195294
# 시퀀스 개수: 195295
# 시퀀스 개수: 195296
# 시퀀스 개수: 195297
# 시퀀스 개수: 195298
# 시퀀스 개수: 195299
# 시퀀스 개수: 195300
# 시퀀스 개수: 195301
# 시퀀스 개수: 195302
# 시퀀스 개수: 195303
# 시퀀스 개수: 195304
# 시퀀스 개수: 195305
# 시퀀스 개수: 195306
# 시퀀스 개수: 195307
# 시퀀스 개수: 195308
# 시퀀스 개수: 195309
# 시퀀스 개수: 195310
# 시퀀스 개수: 195311
# 시퀀스 개수: 195312
# 시퀀스 개수: 195313
# 시퀀스 개수: 195314
# 시퀀스 개수: 195315
# 시퀀스 개수: 195316
# 시퀀스 개수: 195317
# 시퀀스 개수: 195318
# 시퀀스 개수: 195319
# 시퀀스 개수: 195320
# 시퀀스 개수: 195321
# 시퀀스 개수: 195322
# 시퀀스 개수: 195323
# 시퀀스 개수: 195324
# 시퀀스 개수: 195325
# 시퀀스 개수: 195326
# 시퀀스 개수: 195327
# 시퀀스 개수: 195328
# 시퀀스 개수: 195329
# 시퀀스 개수: 195330
# 시퀀스 개수: 195331
# 시퀀스 개수: 195332
# 시퀀스 개수: 195333
# 시퀀스 개수: 195334
# 시퀀스 개수: 195335
# 시퀀스 개수: 195336
# 시퀀스 개수: 195337
# 시퀀스 개수: 195338
# 시퀀스 개수: 195339
# 시퀀스 개수: 195340
# 시퀀스 개수: 195341
# 시퀀스 개수: 195342
# 시퀀스 개수: 195343
# 시퀀스 개수: 195344
# 시퀀스 개수: 195345
# 시퀀스 개수: 195346
# 시퀀스 개수: 195347
# 시퀀스 개수: 195348
# 시퀀스 개수: 195349
# 시퀀스 개수: 195350
# 시퀀스 개수: 195351
# 시퀀스 개수: 195352
# 시퀀스 개수: 195353
# 시퀀스 개수: 195354
# 시퀀스 개수: 195355
# 시퀀스 개수: 195356
# 시퀀스 개수: 195357
# 시퀀스 개수: 195358
# 시퀀스 개수: 195359
# 시퀀스 개수: 195360
# 시퀀스 개수: 195361
# 시퀀스 개수: 195362
# 시퀀스 개수: 195363
# 시퀀스 개수: 195364
# 시퀀스 개수: 195365
# 시퀀스 개수: 195366
# 시퀀스 개수: 195367
# 시퀀스 개수: 195368
# 시퀀스 개수: 195369
# 시퀀스 개수: 195370
# 시퀀스 개수: 195371
# 시퀀스 개수: 195372
# 시퀀스 개수: 195373
# 시퀀스 개수: 195374
# 시퀀스 개수: 195375
# 시퀀스 개수: 195376
# 시퀀스 개수: 195377
# 시퀀스 개수: 195378
# 시퀀스 개수: 195379
# 시퀀스 개수: 195380
# 시퀀스 개수: 195381
# 시퀀스 개수: 195382
# 시퀀스 개수: 195383
# 시퀀스 개수: 195384
# 시퀀스 개수: 195385
# 시퀀스 개수: 195386
# 시퀀스 개수: 195387
# 시퀀스 개수: 195388
# 시퀀스 개수: 195389
# 시퀀스 개수: 195390
# 시퀀스 개수: 195391
# 시퀀스 개수: 195392
# 시퀀스 개수: 195393
# 시퀀스 개수: 195394
# 시퀀스 개수: 195395
# 시퀀스 개수: 195396
# 시퀀스 개수: 195397
# 시퀀스 개수: 195398
# 시퀀스 개수: 195399
# 시퀀스 개수: 195400
# 시퀀스 개수: 195401
# 시퀀스 개수: 195402
# 시퀀스 개수: 195403
# 시퀀스 개수: 195404
# 시퀀스 개수: 195405
# 시퀀스 개수: 195406
# 시퀀스 개수: 195407
# 시퀀스 개수: 195408
# 시퀀스 개수: 195409
# 시퀀스 개수: 195410
# 시퀀스 개수: 195411
# 시퀀스 개수: 195412
# 시퀀스 개수: 195413
# 시퀀스 개수: 195414
# 시퀀스 개수: 195415
# 시퀀스 개수: 195416
# 시퀀스 개수: 195417
# 시퀀스 개수: 195418
# 시퀀스 개수: 195419
# 시퀀스 개수: 195420
# 시퀀스 개수: 195421
# 시퀀스 개수: 195422
# 시퀀스 개수: 195423
# 시퀀스 개수: 195424
# 시퀀스 개수: 195425
# 시퀀스 개수: 195426
# 시퀀스 개수: 195427
# 시퀀스 개수: 195428
# 시퀀스 개수: 195429
# 시퀀스 개수: 195430
# 시퀀스 개수: 195431
# 시퀀스 개수: 195432
# 시퀀스 개수: 195433
# 시퀀스 개수: 195434
# 시퀀스 개수: 195435
# 시퀀스 개수: 195436
# 시퀀스 개수: 195437
# 시퀀스 개수: 195438
# 시퀀스 개수: 195439
# 시퀀스 개수: 195440
# 시퀀스 개수: 195441
# 시퀀스 개수: 195442
# 시퀀스 개수: 195443
# 시퀀스 개수: 195444
# 시퀀스 개수: 195445
# 시퀀스 개수: 195446
# 시퀀스 개수: 195447
# 시퀀스 개수: 195448
# 시퀀스 개수: 195449
# 시퀀스 개수: 195450
# 시퀀스 개수: 195451
# 시퀀스 개수: 195452
# 시퀀스 개수: 195453
# 시퀀스 개수: 195454
# 시퀀스 개수: 195455
# 시퀀스 개수: 195456
# 시퀀스 개수: 195457
# 시퀀스 개수: 195458
# 시퀀스 개수: 195459
# 시퀀스 개수: 195460
# 시퀀스 개수: 195461
# 시퀀스 개수: 195462
# 시퀀스 개수: 195463
# 시퀀스 개수: 195464
# 시퀀스 개수: 195465
# 시퀀스 개수: 195466
# 시퀀스 개수: 195467
# 시퀀스 개수: 195468
# 시퀀스 개수: 195469
# 시퀀스 개수: 195470
# 시퀀스 개수: 195471
# 시퀀스 개수: 195472
# 시퀀스 개수: 195473
# 시퀀스 개수: 195474
# 시퀀스 개수: 195475
# 시퀀스 개수: 195476
# 시퀀스 개수: 195477
# 시퀀스 개수: 195478
# 시퀀스 개수: 195479
# 시퀀스 개수: 195480
# 시퀀스 개수: 195481
# 시퀀스 개수: 195482
# 시퀀스 개수: 195483
# 시퀀스 개수: 195484
# 시퀀스 개수: 195485
# 시퀀스 개수: 195486
# 시퀀스 개수: 195487
# 시퀀스 개수: 195488
# 시퀀스 개수: 195489
# 시퀀스 개수: 195490
# 시퀀스 개수: 195491
# 시퀀스 개수: 195492
# 시퀀스 개수: 195493
# 시퀀스 개수: 195494
# 시퀀스 개수: 195495
# 시퀀스 개수: 195496
# 시퀀스 개수: 195497
# 시퀀스 개수: 195498
# 시퀀스 개수: 195499
# 시퀀스 개수: 195500
# 시퀀스 개수: 195501
# 시퀀스 개수: 195502
# 시퀀스 개수: 195503
# 시퀀스 개수: 195504
# 시퀀스 개수: 195505
# 시퀀스 개수: 195506
# 시퀀스 개수: 195507
# 시퀀스 개수: 195508
# 시퀀스 개수: 195509
# 시퀀스 개수: 195510
# 시퀀스 개수: 195511
# 시퀀스 개수: 195512
# 시퀀스 개수: 195513
# 시퀀스 개수: 195514
# 시퀀스 개수: 195515
# 시퀀스 개수: 195516
# 시퀀스 개수: 195517
# 시퀀스 개수: 195518
# 시퀀스 개수: 195519
# 시퀀스 개수: 195520
# 시퀀스 개수: 195521
# 시퀀스 개수: 195522
# 시퀀스 개수: 195523
# 시퀀스 개수: 195524
# 시퀀스 개수: 195525
# 시퀀스 개수: 195526
# 시퀀스 개수: 195527
# 시퀀스 개수: 195528
# 시퀀스 개수: 195529
# 시퀀스 개수: 195530
# 시퀀스 개수: 195531
# 시퀀스 개수: 195532
# 시퀀스 개수: 195533
# 시퀀스 개수: 195534
# 시퀀스 개수: 195535
# 시퀀스 개수: 195536
# 시퀀스 개수: 195537
# 시퀀스 개수: 195538
# 시퀀스 개수: 195539
# 시퀀스 개수: 195540
# 시퀀스 개수: 195541
# 시퀀스 개수: 195542
# 시퀀스 개수: 195543
# 시퀀스 개수: 195544
# 시퀀스 개수: 195545
# 시퀀스 개수: 195546
# 시퀀스 개수: 195547
# 시퀀스 개수: 195548
# 시퀀스 개수: 195549
# 시퀀스 개수: 195550
# 시퀀스 개수: 195551
# 시퀀스 개수: 195552
# 시퀀스 개수: 195553
# 시퀀스 개수: 195554
# 시퀀스 개수: 195555
# 시퀀스 개수: 195556
# 시퀀스 개수: 195557
# 시퀀스 개수: 195558
# 시퀀스 개수: 195559
# 시퀀스 개수: 195560
# 시퀀스 개수: 195561
# 시퀀스 개수: 195562
# 시퀀스 개수: 195563
# 시퀀스 개수: 195564
# 시퀀스 개수: 195565
# 시퀀스 개수: 195566
# 시퀀스 개수: 195567
# 시퀀스 개수: 195568
# 시퀀스 개수: 195569
# 시퀀스 개수: 195570
# 시퀀스 개수: 195571
# 시퀀스 개수: 195572
# 시퀀스 개수: 195573
# 시퀀스 개수: 195574
# 시퀀스 개수: 195575
# 시퀀스 개수: 195576
# 시퀀스 개수: 195577
# 시퀀스 개수: 195578
# 시퀀스 개수: 195579
# 시퀀스 개수: 195580
# 시퀀스 개수: 195581
# 시퀀스 개수: 195582
# 시퀀스 개수: 195583
# 시퀀스 개수: 195584
# 시퀀스 개수: 195585
# 시퀀스 개수: 195586
# 시퀀스 개수: 195587
# 시퀀스 개수: 195588
# 시퀀스 개수: 195589
# 시퀀스 개수: 195590
# 시퀀스 개수: 195591
# 시퀀스 개수: 195592
# 시퀀스 개수: 195593
# 시퀀스 개수: 195594
# 시퀀스 개수: 195595
# 시퀀스 개수: 195596
# 시퀀스 개수: 195597
# 시퀀스 개수: 195598
# 시퀀스 개수: 195599
# 시퀀스 개수: 195600
# 시퀀스 개수: 195601
# 시퀀스 개수: 195602
# 시퀀스 개수: 195603
# 시퀀스 개수: 195604
# 시퀀스 개수: 195605
# 시퀀스 개수: 195606
# 시퀀스 개수: 195607
# 시퀀스 개수: 195608
# 시퀀스 개수: 195609
# 시퀀스 개수: 195610
# 시퀀스 개수: 195611
# 시퀀스 개수: 195612
# 시퀀스 개수: 195613
# 시퀀스 개수: 195614
# 시퀀스 개수: 195615
# 시퀀스 개수: 195616
# 시퀀스 개수: 195617
# 시퀀스 개수: 195618
# 시퀀스 개수: 195619
# 시퀀스 개수: 195620
# 시퀀스 개수: 195621
# 시퀀스 개수: 195622
# 시퀀스 개수: 195623
# 시퀀스 개수: 195624
# 시퀀스 개수: 195625
# 시퀀스 개수: 195626
# 시퀀스 개수: 195627
# 시퀀스 개수: 195628
# 시퀀스 개수: 195629
# 시퀀스 개수: 195630
# 시퀀스 개수: 195631
# 시퀀스 개수: 195632
# 시퀀스 개수: 195633
# 시퀀스 개수: 195634
# 시퀀스 개수: 195635
# 시퀀스 개수: 195636
# 시퀀스 개수: 195637
# 시퀀스 개수: 195638
# 시퀀스 개수: 195639
# 시퀀스 개수: 195640
# 시퀀스 개수: 195641
# 시퀀스 개수: 195642
# 시퀀스 개수: 195643
# 시퀀스 개수: 195644
# 시퀀스 개수: 195645
# 시퀀스 개수: 195646
# 시퀀스 개수: 195647
# 시퀀스 개수: 195648
# 시퀀스 개수: 195649
# 시퀀스 개수: 195650
# 시퀀스 개수: 195651
# 시퀀스 개수: 195652
# 시퀀스 개수: 195653
# 시퀀스 개수: 195654
# 시퀀스 개수: 195655
# 시퀀스 개수: 195656
# 시퀀스 개수: 195657
# 시퀀스 개수: 195658
# 시퀀스 개수: 195659
# 시퀀스 개수: 195660
# 시퀀스 개수: 195661
# 시퀀스 개수: 195662
# 시퀀스 개수: 195663
# 시퀀스 개수: 195664
# 시퀀스 개수: 195665
# 시퀀스 개수: 195666
# 시퀀스 개수: 195667
# 시퀀스 개수: 195668
# 시퀀스 개수: 195669
# 시퀀스 개수: 195670
# 시퀀스 개수: 195671
# 시퀀스 개수: 195672
# 시퀀스 개수: 195673
# 시퀀스 개수: 195674
# 시퀀스 개수: 195675
# 시퀀스 개수: 195676
# 시퀀스 개수: 195677
# 시퀀스 개수: 195678
# 시퀀스 개수: 195679
# 시퀀스 개수: 195680
# 시퀀스 개수: 195681
# 시퀀스 개수: 195682
# 시퀀스 개수: 195683
# 시퀀스 개수: 195684
# 시퀀스 개수: 195685
# 시퀀스 개수: 195686
# 시퀀스 개수: 195687
# 시퀀스 개수: 195688
# 시퀀스 개수: 195689
# 시퀀스 개수: 195690
# 시퀀스 개수: 195691
# 시퀀스 개수: 195692
# 시퀀스 개수: 195693
# 시퀀스 개수: 195694
# 시퀀스 개수: 195695
# 시퀀스 개수: 195696
# 시퀀스 개수: 195697
# 시퀀스 개수: 195698
# 시퀀스 개수: 195699
# 시퀀스 개수: 195700
# 시퀀스 개수: 195701
# 시퀀스 개수: 195702
# 시퀀스 개수: 195703
# 시퀀스 개수: 195704
# 시퀀스 개수: 195705
# 시퀀스 개수: 195706
# 시퀀스 개수: 195707
# 시퀀스 개수: 195708
# 시퀀스 개수: 195709
# 시퀀스 개수: 195710
# 시퀀스 개수: 195711
# 시퀀스 개수: 195712
# 시퀀스 개수: 195713
# 시퀀스 개수: 195714
# 시퀀스 개수: 195715
# 시퀀스 개수: 195716
# 시퀀스 개수: 195717
# 시퀀스 개수: 195718
# 시퀀스 개수: 195719
# 시퀀스 개수: 195720
# 시퀀스 개수: 195721
# 시퀀스 개수: 195722
# 시퀀스 개수: 195723
# 시퀀스 개수: 195724
# 시퀀스 개수: 195725
# 시퀀스 개수: 195726
# 시퀀스 개수: 195727
# 시퀀스 개수: 195728
# 시퀀스 개수: 195729
# 시퀀스 개수: 195730
# 시퀀스 개수: 195731
# 시퀀스 개수: 195732
# 시퀀스 개수: 195733
# 시퀀스 개수: 195734
# 시퀀스 개수: 195735
# 시퀀스 개수: 195736
# 시퀀스 개수: 195737
# 시퀀스 개수: 195738
# 시퀀스 개수: 195739
# 시퀀스 개수: 195740
# 시퀀스 개수: 195741
# 시퀀스 개수: 195742
# 시퀀스 개수: 195743
# 시퀀스 개수: 195744
# 시퀀스 개수: 195745
# 시퀀스 개수: 195746
# 시퀀스 개수: 195747
# 시퀀스 개수: 195748
# 시퀀스 개수: 195749
# 시퀀스 개수: 195750
# 시퀀스 개수: 195751
# 시퀀스 개수: 195752
# 시퀀스 개수: 195753
# 시퀀스 개수: 195754
# 시퀀스 개수: 195755
# 시퀀스 개수: 195756
# 시퀀스 개수: 195757
# 시퀀스 개수: 195758
# 시퀀스 개수: 195759
# 시퀀스 개수: 195760
# 시퀀스 개수: 195761
# 시퀀스 개수: 195762
# 시퀀스 개수: 195763
# 시퀀스 개수: 195764
# 시퀀스 개수: 195765
# 시퀀스 개수: 195766
# 시퀀스 개수: 195767
# 시퀀스 개수: 195768
# 시퀀스 개수: 195769
# 시퀀스 개수: 195770
# 시퀀스 개수: 195771
# 시퀀스 개수: 195772
# 시퀀스 개수: 195773
# 시퀀스 개수: 195774
# 시퀀스 개수: 195775
# 시퀀스 개수: 195776
# 시퀀스 개수: 195777
# 시퀀스 개수: 195778
# 시퀀스 개수: 195779
# 시퀀스 개수: 195780
# 시퀀스 개수: 195781
# 시퀀스 개수: 195782
# 시퀀스 개수: 195783
# 시퀀스 개수: 195784
# 시퀀스 개수: 195785
# 시퀀스 개수: 195786
# 시퀀스 개수: 195787
# 시퀀스 개수: 195788
# 시퀀스 개수: 195789
# 시퀀스 개수: 195790
# 시퀀스 개수: 195791
# 시퀀스 개수: 195792
# 시퀀스 개수: 195793
# 시퀀스 개수: 195794
# 시퀀스 개수: 195795
# 시퀀스 개수: 195796
# 시퀀스 개수: 195797
# 시퀀스 개수: 195798
# 시퀀스 개수: 195799
# 시퀀스 개수: 195800
# 시퀀스 개수: 195801
# 시퀀스 개수: 195802
# 시퀀스 개수: 195803
# 시퀀스 개수: 195804
# 시퀀스 개수: 195805
# 시퀀스 개수: 195806
# 시퀀스 개수: 195807
# 시퀀스 개수: 195808
# 시퀀스 개수: 195809
# 시퀀스 개수: 195810
# 시퀀스 개수: 195811
# 시퀀스 개수: 195812
# 시퀀스 개수: 195813
# 시퀀스 개수: 195814
# 시퀀스 개수: 195815
# 시퀀스 개수: 195816
# 시퀀스 개수: 195817
# 시퀀스 개수: 195818
# 시퀀스 개수: 195819
# 시퀀스 개수: 195820
# 시퀀스 개수: 195821
# 시퀀스 개수: 195822
# 시퀀스 개수: 195823
# 시퀀스 개수: 195824
# 시퀀스 개수: 195825
# 시퀀스 개수: 195826
# 시퀀스 개수: 195827
# 시퀀스 개수: 195828
# 시퀀스 개수: 195829
# 시퀀스 개수: 195830
# 시퀀스 개수: 195831
# 시퀀스 개수: 195832
# 시퀀스 개수: 195833
# 시퀀스 개수: 195834
# 시퀀스 개수: 195835
# 시퀀스 개수: 195836
# 시퀀스 개수: 195837
# 시퀀스 개수: 195838
# 시퀀스 개수: 195839
# 시퀀스 개수: 195840
# 시퀀스 개수: 195841
# 시퀀스 개수: 195842
# 시퀀스 개수: 195843
# 시퀀스 개수: 195844
# 시퀀스 개수: 195845
# 시퀀스 개수: 195846
# 시퀀스 개수: 195847
# 시퀀스 개수: 195848
# 시퀀스 개수: 195849
# 시퀀스 개수: 195850
# 시퀀스 개수: 195851
# 시퀀스 개수: 195852
# 시퀀스 개수: 195853
# 시퀀스 개수: 195854
# 시퀀스 개수: 195855
# 시퀀스 개수: 195856
# 시퀀스 개수: 195857
# 시퀀스 개수: 195858
# 시퀀스 개수: 195859
# 시퀀스 개수: 195860
# 시퀀스 개수: 195861
# 시퀀스 개수: 195862
# 시퀀스 개수: 195863
# 시퀀스 개수: 195864
# 시퀀스 개수: 195865
# 시퀀스 개수: 195866
# 시퀀스 개수: 195867
# 시퀀스 개수: 195868
# 시퀀스 개수: 195869
# 시퀀스 개수: 195870
# 시퀀스 개수: 195871
# 시퀀스 개수: 195872
# 시퀀스 개수: 195873
# 시퀀스 개수: 195874
# 시퀀스 개수: 195875
# 시퀀스 개수: 195876
# 시퀀스 개수: 195877
# 시퀀스 개수: 195878
# 시퀀스 개수: 195879
# 시퀀스 개수: 195880
# 시퀀스 개수: 195881
# 시퀀스 개수: 195882
# 시퀀스 개수: 195883
# 시퀀스 개수: 195884
# 시퀀스 개수: 195885
# 시퀀스 개수: 195886
# 시퀀스 개수: 195887
# 시퀀스 개수: 195888
# 시퀀스 개수: 195889
# 시퀀스 개수: 195890
# 시퀀스 개수: 195891
# 시퀀스 개수: 195892
# 시퀀스 개수: 195893
# 시퀀스 개수: 195894
# 시퀀스 개수: 195895
# 시퀀스 개수: 195896
# 시퀀스 개수: 195897
# 시퀀스 개수: 195898
# 시퀀스 개수: 195899
# 시퀀스 개수: 195900
# 시퀀스 개수: 195901
# 시퀀스 개수: 195902
# 시퀀스 개수: 195903
# 시퀀스 개수: 195904
# 시퀀스 개수: 195905
# 시퀀스 개수: 195906
# 시퀀스 개수: 195907
# 시퀀스 개수: 195908
# 시퀀스 개수: 195909
# 시퀀스 개수: 195910
# 시퀀스 개수: 195911
# 시퀀스 개수: 195912
# 시퀀스 개수: 195913
# 시퀀스 개수: 195914
# 시퀀스 개수: 195915
# 시퀀스 개수: 195916
# 시퀀스 개수: 195917
# 시퀀스 개수: 195918
# 시퀀스 개수: 195919
# 시퀀스 개수: 195920
# 시퀀스 개수: 195921
# 시퀀스 개수: 195922
# 시퀀스 개수: 195923
# 시퀀스 개수: 195924
# 시퀀스 개수: 195925
# 시퀀스 개수: 195926
# 시퀀스 개수: 195927
# 시퀀스 개수: 195928
# 시퀀스 개수: 195929
# 시퀀스 개수: 195930
# 시퀀스 개수: 195931
# 시퀀스 개수: 195932
# 시퀀스 개수: 195933
# 시퀀스 개수: 195934
# 시퀀스 개수: 195935
# 시퀀스 개수: 195936
# 시퀀스 개수: 195937
# 시퀀스 개수: 195938
# 시퀀스 개수: 195939
# 시퀀스 개수: 195940
# 시퀀스 개수: 195941
# 시퀀스 개수: 195942
# 시퀀스 개수: 195943
# 시퀀스 개수: 195944
# 시퀀스 개수: 195945
# 시퀀스 개수: 195946
# 시퀀스 개수: 195947
# 시퀀스 개수: 195948
# 시퀀스 개수: 195949
# 시퀀스 개수: 195950
# 시퀀스 개수: 195951
# 시퀀스 개수: 195952
# 시퀀스 개수: 195953
# 시퀀스 개수: 195954
# 시퀀스 개수: 195955
# 시퀀스 개수: 195956
# 시퀀스 개수: 195957
# 시퀀스 개수: 195958
# 시퀀스 개수: 195959
# 시퀀스 개수: 195960
# 시퀀스 개수: 195961
# 시퀀스 개수: 195962
# 시퀀스 개수: 195963
# 시퀀스 개수: 195964
# 시퀀스 개수: 195965
# 시퀀스 개수: 195966
# 시퀀스 개수: 195967
# 시퀀스 개수: 195968
# 시퀀스 개수: 195969
# 시퀀스 개수: 195970
# 시퀀스 개수: 195971
# 시퀀스 개수: 195972
# 시퀀스 개수: 195973
# 시퀀스 개수: 195974
# 시퀀스 개수: 195975
# 시퀀스 개수: 195976
# 시퀀스 개수: 195977
# 시퀀스 개수: 195978
# 시퀀스 개수: 195979
# 시퀀스 개수: 195980
# 시퀀스 개수: 195981
# 시퀀스 개수: 195982
# 시퀀스 개수: 195983
# 시퀀스 개수: 195984
# 시퀀스 개수: 195985
# 시퀀스 개수: 195986
# 시퀀스 개수: 195987
# 시퀀스 개수: 195988
# 시퀀스 개수: 195989
# 시퀀스 개수: 195990
# 시퀀스 개수: 195991
# 시퀀스 개수: 195992
# 시퀀스 개수: 195993
# 시퀀스 개수: 195994
# 시퀀스 개수: 195995
# 시퀀스 개수: 195996
# 시퀀스 개수: 195997
# 시퀀스 개수: 195998
# 시퀀스 개수: 195999
# 시퀀스 개수: 196000
# 시퀀스 개수: 196001
# 시퀀스 개수: 196002
# 시퀀스 개수: 196003
# 시퀀스 개수: 196004
# 시퀀스 개수: 196005
# 시퀀스 개수: 196006
# 시퀀스 개수: 196007
# 시퀀스 개수: 196008
# 시퀀스 개수: 196009
# 시퀀스 개수: 196010
# 시퀀스 개수: 196011
# 시퀀스 개수: 196012
# 시퀀스 개수: 196013
# 시퀀스 개수: 196014
# 시퀀스 개수: 196015
# 시퀀스 개수: 196016
# 시퀀스 개수: 196017
# 시퀀스 개수: 196018
# 시퀀스 개수: 196019
# 시퀀스 개수: 196020
# 시퀀스 개수: 196021
# 시퀀스 개수: 196022
# 시퀀스 개수: 196023
# 시퀀스 개수: 196024
# 시퀀스 개수: 196025
# 시퀀스 개수: 196026
# 시퀀스 개수: 196027
# 시퀀스 개수: 196028
# 시퀀스 개수: 196029
# 시퀀스 개수: 196030
# 시퀀스 개수: 196031
# 시퀀스 개수: 196032
# 시퀀스 개수: 196033
# 시퀀스 개수: 196034
# 시퀀스 개수: 196035
# 시퀀스 개수: 196036
# 시퀀스 개수: 196037
# 시퀀스 개수: 196038
# 시퀀스 개수: 196039
# 시퀀스 개수: 196040
# 시퀀스 개수: 196041
# 시퀀스 개수: 196042
# 시퀀스 개수: 196043
# 시퀀스 개수: 196044
# 시퀀스 개수: 196045
# 시퀀스 개수: 196046
# 시퀀스 개수: 196047
# 시퀀스 개수: 196048
# 시퀀스 개수: 196049
# 시퀀스 개수: 196050
# 시퀀스 개수: 196051
# 시퀀스 개수: 196052
# 시퀀스 개수: 196053
# 시퀀스 개수: 196054
# 시퀀스 개수: 196055
# 시퀀스 개수: 196056
# 시퀀스 개수: 196057
# 시퀀스 개수: 196058
# 시퀀스 개수: 196059
# 시퀀스 개수: 196060
# 시퀀스 개수: 196061
# 시퀀스 개수: 196062
# 시퀀스 개수: 196063
# 시퀀스 개수: 196064
# 시퀀스 개수: 196065
# 시퀀스 개수: 196066
# 시퀀스 개수: 196067
# 시퀀스 개수: 196068
# 시퀀스 개수: 196069
# 시퀀스 개수: 196070
# 시퀀스 개수: 196071
# 시퀀스 개수: 196072
# 시퀀스 개수: 196073
# 시퀀스 개수: 196074
# 시퀀스 개수: 196075
# 시퀀스 개수: 196076
# 시퀀스 개수: 196077
# 시퀀스 개수: 196078
# 시퀀스 개수: 196079
# 시퀀스 개수: 196080
# 시퀀스 개수: 196081
# 시퀀스 개수: 196082
# 시퀀스 개수: 196083
# 시퀀스 개수: 196084
# 시퀀스 개수: 196085
# 시퀀스 개수: 196086
# 시퀀스 개수: 196087
# 시퀀스 개수: 196088
# 시퀀스 개수: 196089
# 시퀀스 개수: 196090
# 시퀀스 개수: 196091
# 시퀀스 개수: 196092
# 시퀀스 개수: 196093
# 시퀀스 개수: 196094
# 시퀀스 개수: 196095
# 시퀀스 개수: 196096
# 시퀀스 개수: 196097
# 시퀀스 개수: 196098
# 시퀀스 개수: 196099
# 시퀀스 개수: 196100
# 시퀀스 개수: 196101
# 시퀀스 개수: 196102
# 시퀀스 개수: 196103
# 시퀀스 개수: 196104
# 시퀀스 개수: 196105
# 시퀀스 개수: 196106
# 시퀀스 개수: 196107
# 시퀀스 개수: 196108
# 시퀀스 개수: 196109
# 시퀀스 개수: 196110
# 시퀀스 개수: 196111
# 시퀀스 개수: 196112
# 시퀀스 개수: 196113
# 시퀀스 개수: 196114
# 시퀀스 개수: 196115
# 시퀀스 개수: 196116
# 시퀀스 개수: 196117
# 시퀀스 개수: 196118
# 시퀀스 개수: 196119
# 시퀀스 개수: 196120
# 시퀀스 개수: 196121
# 시퀀스 개수: 196122
# 시퀀스 개수: 196123
# 시퀀스 개수: 196124
# 시퀀스 개수: 196125
# 시퀀스 개수: 196126
# 시퀀스 개수: 196127
# 시퀀스 개수: 196128
# 시퀀스 개수: 196129
# 시퀀스 개수: 196130
# 시퀀스 개수: 196131
# 시퀀스 개수: 196132
# 시퀀스 개수: 196133
# 시퀀스 개수: 196134
# 시퀀스 개수: 196135
# 시퀀스 개수: 196136
# 시퀀스 개수: 196137
# 시퀀스 개수: 196138
# 시퀀스 개수: 196139
# 시퀀스 개수: 196140
# 시퀀스 개수: 196141
# 시퀀스 개수: 196142
# 시퀀스 개수: 196143
# 시퀀스 개수: 196144
# 시퀀스 개수: 196145
# 시퀀스 개수: 196146
# 시퀀스 개수: 196147
# 시퀀스 개수: 196148
# 시퀀스 개수: 196149
# 시퀀스 개수: 196150
# 시퀀스 개수: 196151
# 시퀀스 개수: 196152
# 시퀀스 개수: 196153
# 시퀀스 개수: 196154
# 시퀀스 개수: 196155
# 시퀀스 개수: 196156
# 시퀀스 개수: 196157
# 시퀀스 개수: 196158
# 시퀀스 개수: 196159
# 시퀀스 개수: 196160
# 시퀀스 개수: 196161
# 시퀀스 개수: 196162
# 시퀀스 개수: 196163
# 시퀀스 개수: 196164
# 시퀀스 개수: 196165
# 시퀀스 개수: 196166
# 시퀀스 개수: 196167
# 시퀀스 개수: 196168
# 시퀀스 개수: 196169
# 시퀀스 개수: 196170
# 시퀀스 개수: 196171
# 시퀀스 개수: 196172
# 시퀀스 개수: 196173
# 시퀀스 개수: 196174
# 시퀀스 개수: 196175
# 시퀀스 개수: 196176
# 시퀀스 개수: 196177
# 시퀀스 개수: 196178
# 시퀀스 개수: 196179
# 시퀀스 개수: 196180
# 시퀀스 개수: 196181
# 시퀀스 개수: 196182
# 시퀀스 개수: 196183
# 시퀀스 개수: 196184
# 시퀀스 개수: 196185
# 시퀀스 개수: 196186
# 시퀀스 개수: 196187
# 시퀀스 개수: 196188
# 시퀀스 개수: 196189
# 시퀀스 개수: 196190
# 시퀀스 개수: 196191
# 시퀀스 개수: 196192
# 시퀀스 개수: 196193
# 시퀀스 개수: 196194
# 시퀀스 개수: 196195
# 시퀀스 개수: 196196
# 시퀀스 개수: 196197
# 시퀀스 개수: 196198
# 시퀀스 개수: 196199
# 시퀀스 개수: 196200
# 시퀀스 개수: 196201
# 시퀀스 개수: 196202
# 시퀀스 개수: 196203
# 시퀀스 개수: 196204
# 시퀀스 개수: 196205
# 시퀀스 개수: 196206
# 시퀀스 개수: 196207
# 시퀀스 개수: 196208
# 시퀀스 개수: 196209
# 시퀀스 개수: 196210
# 시퀀스 개수: 196211
# 시퀀스 개수: 196212
# 시퀀스 개수: 196213
# 시퀀스 개수: 196214
# 시퀀스 개수: 196215
# 시퀀스 개수: 196216
# 시퀀스 개수: 196217
# 시퀀스 개수: 196218
# 시퀀스 개수: 196219
# 시퀀스 개수: 196220
# 시퀀스 개수: 196221
# 시퀀스 개수: 196222
# 시퀀스 개수: 196223
# 시퀀스 개수: 196224
# 시퀀스 개수: 196225
# 시퀀스 개수: 196226
# 시퀀스 개수: 196227
# 시퀀스 개수: 196228
# 시퀀스 개수: 196229
# 시퀀스 개수: 196230
# 시퀀스 개수: 196231
# 시퀀스 개수: 196232
# 시퀀스 개수: 196233
# 시퀀스 개수: 196234
# 시퀀스 개수: 196235
# 시퀀스 개수: 196236
# 시퀀스 개수: 196237
# 시퀀스 개수: 196238
# 시퀀스 개수: 196239
# 시퀀스 개수: 196240
# 시퀀스 개수: 196241
# 시퀀스 개수: 196242
# 시퀀스 개수: 196243
# 시퀀스 개수: 196244
# 시퀀스 개수: 196245
# 시퀀스 개수: 196246
# 시퀀스 개수: 196247
# 시퀀스 개수: 196248
# 시퀀스 개수: 196249
# 시퀀스 개수: 196250
# 시퀀스 개수: 196251
# 시퀀스 개수: 196252
# 시퀀스 개수: 196253
# 시퀀스 개수: 196254
# 시퀀스 개수: 196255
# 시퀀스 개수: 196256
# 시퀀스 개수: 196257
# 시퀀스 개수: 196258
# 시퀀스 개수: 196259
# 시퀀스 개수: 196260
# 시퀀스 개수: 196261
# 시퀀스 개수: 196262
# 시퀀스 개수: 196263
# 시퀀스 개수: 196264
# 시퀀스 개수: 196265
# 시퀀스 개수: 196266
# 시퀀스 개수: 196267
# 시퀀스 개수: 196268
# 시퀀스 개수: 196269
# 시퀀스 개수: 196270
# 시퀀스 개수: 196271
# 시퀀스 개수: 196272
# 시퀀스 개수: 196273
# 시퀀스 개수: 196274
# 시퀀스 개수: 196275
# 시퀀스 개수: 196276
# 시퀀스 개수: 196277
# 시퀀스 개수: 196278
# 시퀀스 개수: 196279
# 시퀀스 개수: 196280
# 시퀀스 개수: 196281
# 시퀀스 개수: 196282
# 시퀀스 개수: 196283
# 시퀀스 개수: 196284
# 시퀀스 개수: 196285
# 시퀀스 개수: 196286
# 시퀀스 개수: 196287
# 시퀀스 개수: 196288
# 시퀀스 개수: 196289
# 시퀀스 개수: 196290
# 시퀀스 개수: 196291
# 시퀀스 개수: 196292
# 시퀀스 개수: 196293
# 시퀀스 개수: 196294
# 시퀀스 개수: 196295
# 시퀀스 개수: 196296
# 시퀀스 개수: 196297
# 시퀀스 개수: 196298
# 시퀀스 개수: 196299
# 시퀀스 개수: 196300
# 시퀀스 개수: 196301
# 시퀀스 개수: 196302
# 시퀀스 개수: 196303
# 시퀀스 개수: 196304
# 시퀀스 개수: 196305
# 시퀀스 개수: 196306
# 시퀀스 개수: 196307
# 시퀀스 개수: 196308
# 시퀀스 개수: 196309
# 시퀀스 개수: 196310
# 시퀀스 개수: 196311
# 시퀀스 개수: 196312
# 시퀀스 개수: 196313
# 시퀀스 개수: 196314
# 시퀀스 개수: 196315
# 시퀀스 개수: 196316
# 시퀀스 개수: 196317
# 시퀀스 개수: 196318
# 시퀀스 개수: 196319
# 시퀀스 개수: 196320
# 시퀀스 개수: 196321
# 시퀀스 개수: 196322
# 시퀀스 개수: 196323
# 시퀀스 개수: 196324
# 시퀀스 개수: 196325
# 시퀀스 개수: 196326
# 시퀀스 개수: 196327
# 시퀀스 개수: 196328
# 시퀀스 개수: 196329
# 시퀀스 개수: 196330
# 시퀀스 개수: 196331
# 시퀀스 개수: 196332
# 시퀀스 개수: 196333
# 시퀀스 개수: 196334
# 시퀀스 개수: 196335
# 시퀀스 개수: 196336
# 시퀀스 개수: 196337
# 시퀀스 개수: 196338
# 시퀀스 개수: 196339
# 시퀀스 개수: 196340
# 시퀀스 개수: 196341
# 시퀀스 개수: 196342
# 시퀀스 개수: 196343
# 시퀀스 개수: 196344
# 시퀀스 개수: 196345
# 시퀀스 개수: 196346
# 시퀀스 개수: 196347
# 시퀀스 개수: 196348
# 시퀀스 개수: 196349
# 시퀀스 개수: 196350
# 시퀀스 개수: 196351
# 시퀀스 개수: 196352
# 시퀀스 개수: 196353
# 시퀀스 개수: 196354
# 시퀀스 개수: 196355
# 시퀀스 개수: 196356
# 시퀀스 개수: 196357
# 시퀀스 개수: 196358
# 시퀀스 개수: 196359
# 시퀀스 개수: 196360
# 시퀀스 개수: 196361
# 시퀀스 개수: 196362
# 시퀀스 개수: 196363
# 시퀀스 개수: 196364
# 시퀀스 개수: 196365
# 시퀀스 개수: 196366
# 시퀀스 개수: 196367
# 시퀀스 개수: 196368
# 시퀀스 개수: 196369
# 시퀀스 개수: 196370
# 시퀀스 개수: 196371
# 시퀀스 개수: 196372
# 시퀀스 개수: 196373
# 시퀀스 개수: 196374
# 시퀀스 개수: 196375
# 시퀀스 개수: 196376
# 시퀀스 개수: 196377
# 시퀀스 개수: 196378
# 시퀀스 개수: 196379
# 시퀀스 개수: 196380
# 시퀀스 개수: 196381
# 시퀀스 개수: 196382
# 시퀀스 개수: 196383
# 시퀀스 개수: 196384
# 시퀀스 개수: 196385
# 시퀀스 개수: 196386
# 시퀀스 개수: 196387
# 시퀀스 개수: 196388
# 시퀀스 개수: 196389
# 시퀀스 개수: 196390
# 시퀀스 개수: 196391
# 시퀀스 개수: 196392
# 시퀀스 개수: 196393
# 시퀀스 개수: 196394
# 시퀀스 개수: 196395
# 시퀀스 개수: 196396
# 시퀀스 개수: 196397
# 시퀀스 개수: 196398
# 시퀀스 개수: 196399
# 시퀀스 개수: 196400
# 시퀀스 개수: 196401
# 시퀀스 개수: 196402
# 시퀀스 개수: 196403
# 시퀀스 개수: 196404
# 시퀀스 개수: 196405
# 시퀀스 개수: 196406
# 시퀀스 개수: 196407
# 시퀀스 개수: 196408
# 시퀀스 개수: 196409
# 시퀀스 개수: 196410
# 시퀀스 개수: 196411
# 시퀀스 개수: 196412
# 시퀀스 개수: 196413
# 시퀀스 개수: 196414
# 시퀀스 개수: 196415
# 시퀀스 개수: 196416
# 시퀀스 개수: 196417
# 시퀀스 개수: 196418
# 시퀀스 개수: 196419
# 시퀀스 개수: 196420
# 시퀀스 개수: 196421
# 시퀀스 개수: 196422
# 시퀀스 개수: 196423
# 시퀀스 개수: 196424
# 시퀀스 개수: 196425
# 시퀀스 개수: 196426
# 시퀀스 개수: 196427
# 시퀀스 개수: 196428
# 시퀀스 개수: 196429
# 시퀀스 개수: 196430
# 시퀀스 개수: 196431
# 시퀀스 개수: 196432
# 시퀀스 개수: 196433
# 시퀀스 개수: 196434
# 시퀀스 개수: 196435
# 시퀀스 개수: 196436
# 시퀀스 개수: 196437
# 시퀀스 개수: 196438
# 시퀀스 개수: 196439
# 시퀀스 개수: 196440
# 시퀀스 개수: 196441
# 시퀀스 개수: 196442
# 시퀀스 개수: 196443
# 시퀀스 개수: 196444
# 시퀀스 개수: 196445
# 시퀀스 개수: 196446
# 시퀀스 개수: 196447
# 시퀀스 개수: 196448
# 시퀀스 개수: 196449
# 시퀀스 개수: 196450
# 시퀀스 개수: 196451
# 시퀀스 개수: 196452
# 시퀀스 개수: 196453
# 시퀀스 개수: 196454
# 시퀀스 개수: 196455
# 시퀀스 개수: 196456
# 시퀀스 개수: 196457
# 시퀀스 개수: 196458
# 시퀀스 개수: 196459
# 시퀀스 개수: 196460
# 시퀀스 개수: 196461
# 시퀀스 개수: 196462
# 시퀀스 개수: 196463
# 시퀀스 개수: 196464
# 시퀀스 개수: 196465
# 시퀀스 개수: 196466
# 시퀀스 개수: 196467
# 시퀀스 개수: 196468
# 시퀀스 개수: 196469
# 시퀀스 개수: 196470
# 시퀀스 개수: 196471
# 시퀀스 개수: 196472
# 시퀀스 개수: 196473
# 시퀀스 개수: 196474
# 시퀀스 개수: 196475
# 시퀀스 개수: 196476
# 시퀀스 개수: 196477
# 시퀀스 개수: 196478
# 시퀀스 개수: 196479
# 시퀀스 개수: 196480
# 시퀀스 개수: 196481
# 시퀀스 개수: 196482
# 시퀀스 개수: 196483
# 시퀀스 개수: 196484
# 시퀀스 개수: 196485
# 시퀀스 개수: 196486
# 시퀀스 개수: 196487
# 시퀀스 개수: 196488
# 시퀀스 개수: 196489
# 시퀀스 개수: 196490
# 시퀀스 개수: 196491
# 시퀀스 개수: 196492
# 시퀀스 개수: 196493
# 시퀀스 개수: 196494
# 시퀀스 개수: 196495
# 시퀀스 개수: 196496
# 시퀀스 개수: 196497
# 시퀀스 개수: 196498
# 시퀀스 개수: 196499
# 시퀀스 개수: 196500
# 시퀀스 개수: 196501
# 시퀀스 개수: 196502
# 시퀀스 개수: 196503
# 시퀀스 개수: 196504
# 시퀀스 개수: 196505
# 시퀀스 개수: 196506
# 시퀀스 개수: 196507
# 시퀀스 개수: 196508
# 시퀀스 개수: 196509
# 시퀀스 개수: 196510
# 시퀀스 개수: 196511
# 시퀀스 개수: 196512
# 시퀀스 개수: 196513
# 시퀀스 개수: 196514
# 시퀀스 개수: 196515
# 시퀀스 개수: 196516
# 시퀀스 개수: 196517
# 시퀀스 개수: 196518
# 시퀀스 개수: 196519
# 시퀀스 개수: 196520
# 시퀀스 개수: 196521
# 시퀀스 개수: 196522
# 시퀀스 개수: 196523
# 시퀀스 개수: 196524
# 시퀀스 개수: 196525
# 시퀀스 개수: 196526
# 시퀀스 개수: 196527
# 시퀀스 개수: 196528
# 시퀀스 개수: 196529
# 시퀀스 개수: 196530
# 시퀀스 개수: 196531
# 시퀀스 개수: 196532
# 시퀀스 개수: 196533
# 시퀀스 개수: 196534
# 시퀀스 개수: 196535
# 시퀀스 개수: 196536
# 시퀀스 개수: 196537
# 시퀀스 개수: 196538
# 시퀀스 개수: 196539
# 시퀀스 개수: 196540
# 시퀀스 개수: 196541
# 시퀀스 개수: 196542
# 시퀀스 개수: 196543
# 시퀀스 개수: 196544
# 시퀀스 개수: 196545
# 시퀀스 개수: 196546
# 시퀀스 개수: 196547
# 시퀀스 개수: 196548
# 시퀀스 개수: 196549
# 시퀀스 개수: 196550
# 시퀀스 개수: 196551
# 시퀀스 개수: 196552
# 시퀀스 개수: 196553
# 시퀀스 개수: 196554
# 시퀀스 개수: 196555
# 시퀀스 개수: 196556
# 시퀀스 개수: 196557
# 시퀀스 개수: 196558
# 시퀀스 개수: 196559
# 시퀀스 개수: 196560
# 시퀀스 개수: 196561
# 시퀀스 개수: 196562
# 시퀀스 개수: 196563
# 시퀀스 개수: 196564
# 시퀀스 개수: 196565
# 시퀀스 개수: 196566
# 시퀀스 개수: 196567
# 시퀀스 개수: 196568
# 시퀀스 개수: 196569
# 시퀀스 개수: 196570
# 시퀀스 개수: 196571
# 시퀀스 개수: 196572
# 시퀀스 개수: 196573
# 시퀀스 개수: 196574
# 시퀀스 개수: 196575
# 시퀀스 개수: 196576
# 시퀀스 개수: 196577
# 시퀀스 개수: 196578
# 시퀀스 개수: 196579
# 시퀀스 개수: 196580
# 시퀀스 개수: 196581
# 시퀀스 개수: 196582
# 시퀀스 개수: 196583
# 시퀀스 개수: 196584
# 시퀀스 개수: 196585
# 시퀀스 개수: 196586
# 시퀀스 개수: 196587
# 시퀀스 개수: 196588
# 시퀀스 개수: 196589
# 시퀀스 개수: 196590
# 시퀀스 개수: 196591
# 시퀀스 개수: 196592
# 시퀀스 개수: 196593
# 시퀀스 개수: 196594
# 시퀀스 개수: 196595
# 시퀀스 개수: 196596
# 시퀀스 개수: 196597
# 시퀀스 개수: 196598
# 시퀀스 개수: 196599
# 시퀀스 개수: 196600
# 시퀀스 개수: 196601
# 시퀀스 개수: 196602
# 시퀀스 개수: 196603
# 시퀀스 개수: 196604
# 시퀀스 개수: 196605
# 시퀀스 개수: 196606
# 시퀀스 개수: 196607
# 시퀀스 개수: 196608
# 시퀀스 개수: 196609
# 시퀀스 개수: 196610
# 시퀀스 개수: 196611
# 시퀀스 개수: 196612
# 시퀀스 개수: 196613
# 시퀀스 개수: 196614
# 시퀀스 개수: 196615
# 시퀀스 개수: 196616
# 시퀀스 개수: 196617
# 시퀀스 개수: 196618
# 시퀀스 개수: 196619
# 시퀀스 개수: 196620
# 시퀀스 개수: 196621
# 시퀀스 개수: 196622
# 시퀀스 개수: 196623
# 시퀀스 개수: 196624
# 시퀀스 개수: 196625
# 시퀀스 개수: 196626
# 시퀀스 개수: 196627
# 시퀀스 개수: 196628
# 시퀀스 개수: 196629
# 시퀀스 개수: 196630
# 시퀀스 개수: 196631
# 시퀀스 개수: 196632
# 시퀀스 개수: 196633
# 시퀀스 개수: 196634
# 시퀀스 개수: 196635
# 시퀀스 개수: 196636
# 시퀀스 개수: 196637
# 시퀀스 개수: 196638
# 시퀀스 개수: 196639
# 시퀀스 개수: 196640
# 시퀀스 개수: 196641
# 시퀀스 개수: 196642
# 시퀀스 개수: 196643
# 시퀀스 개수: 196644
# 시퀀스 개수: 196645
# 시퀀스 개수: 196646
# 시퀀스 개수: 196647
# 시퀀스 개수: 196648
# 시퀀스 개수: 196649
# 시퀀스 개수: 196650
# 시퀀스 개수: 196651
# 시퀀스 개수: 196652
# 시퀀스 개수: 196653
# 시퀀스 개수: 196654
# 시퀀스 개수: 196655
# 시퀀스 개수: 196656
# 시퀀스 개수: 196657
# 시퀀스 개수: 196658
# 시퀀스 개수: 196659
# 시퀀스 개수: 196660
# 시퀀스 개수: 196661
# 시퀀스 개수: 196662
# 시퀀스 개수: 196663
# 시퀀스 개수: 196664
# 시퀀스 개수: 196665
# 시퀀스 개수: 196666
# 시퀀스 개수: 196667
# 시퀀스 개수: 196668
# 시퀀스 개수: 196669
# 시퀀스 개수: 196670
# 시퀀스 개수: 196671
# 시퀀스 개수: 196672
# 시퀀스 개수: 196673
# 시퀀스 개수: 196674
# 시퀀스 개수: 196675
# 시퀀스 개수: 196676
# 시퀀스 개수: 196677
# 시퀀스 개수: 196678
# 시퀀스 개수: 196679
# 시퀀스 개수: 196680
# 시퀀스 개수: 196681
# 시퀀스 개수: 196682
# 시퀀스 개수: 196683
# 시퀀스 개수: 196684
# 시퀀스 개수: 196685
# 시퀀스 개수: 196686
# 시퀀스 개수: 196687
# 시퀀스 개수: 196688
# 시퀀스 개수: 196689
# 시퀀스 개수: 196690
# 시퀀스 개수: 196691
# 시퀀스 개수: 196692
# 시퀀스 개수: 196693
# 시퀀스 개수: 196694
# 시퀀스 개수: 196695
# 시퀀스 개수: 196696
# 시퀀스 개수: 196697
# 시퀀스 개수: 196698
# 시퀀스 개수: 196699
# 시퀀스 개수: 196700
# 시퀀스 개수: 196701
# 시퀀스 개수: 196702
# 시퀀스 개수: 196703
# 시퀀스 개수: 196704
# 시퀀스 개수: 196705
# 시퀀스 개수: 196706
# 시퀀스 개수: 196707
# 시퀀스 개수: 196708
# 시퀀스 개수: 196709
# 시퀀스 개수: 196710
# 시퀀스 개수: 196711
# 시퀀스 개수: 196712
# 시퀀스 개수: 196713
# 시퀀스 개수: 196714
# 시퀀스 개수: 196715
# 시퀀스 개수: 196716
# 시퀀스 개수: 196717
# 시퀀스 개수: 196718
# 시퀀스 개수: 196719
# 시퀀스 개수: 196720
# 시퀀스 개수: 196721
# 시퀀스 개수: 196722
# 시퀀스 개수: 196723
# 시퀀스 개수: 196724
# 시퀀스 개수: 196725
# 시퀀스 개수: 196726
# 시퀀스 개수: 196727
# 시퀀스 개수: 196728
# 시퀀스 개수: 196729
# 시퀀스 개수: 196730
# 시퀀스 개수: 196731
# 시퀀스 개수: 196732
# 시퀀스 개수: 196733
# 시퀀스 개수: 196734
# 시퀀스 개수: 196735
# 시퀀스 개수: 196736
# 시퀀스 개수: 196737
# 시퀀스 개수: 196738
# 시퀀스 개수: 196739
# 시퀀스 개수: 196740
# 시퀀스 개수: 196741
# 시퀀스 개수: 196742
# 시퀀스 개수: 196743
# 시퀀스 개수: 196744
# 시퀀스 개수: 196745
# 시퀀스 개수: 196746
# 시퀀스 개수: 196747
# 시퀀스 개수: 196748
# 시퀀스 개수: 196749
# 시퀀스 개수: 196750
# 시퀀스 개수: 196751
# 시퀀스 개수: 196752
# 시퀀스 개수: 196753
# 시퀀스 개수: 196754
# 시퀀스 개수: 196755
# 시퀀스 개수: 196756
# 시퀀스 개수: 196757
# 시퀀스 개수: 196758
# 시퀀스 개수: 196759
# 시퀀스 개수: 196760
# 시퀀스 개수: 196761
# 시퀀스 개수: 196762
# 시퀀스 개수: 196763
# 시퀀스 개수: 196764
# 시퀀스 개수: 196765
# 시퀀스 개수: 196766
# 시퀀스 개수: 196767
# 시퀀스 개수: 196768
# 시퀀스 개수: 196769
# 시퀀스 개수: 196770
# 시퀀스 개수: 196771
# 시퀀스 개수: 196772
# 시퀀스 개수: 196773
# 시퀀스 개수: 196774
# 시퀀스 개수: 196775
# 시퀀스 개수: 196776
# 시퀀스 개수: 196777
# 시퀀스 개수: 196778
# 시퀀스 개수: 196779
# 시퀀스 개수: 196780
# 시퀀스 개수: 196781
# 시퀀스 개수: 196782
# 시퀀스 개수: 196783
# 시퀀스 개수: 196784
# 시퀀스 개수: 196785
# 시퀀스 개수: 196786
# 시퀀스 개수: 196787
# 시퀀스 개수: 196788
# 시퀀스 개수: 196789
# 시퀀스 개수: 196790
# 시퀀스 개수: 196791
# 시퀀스 개수: 196792
# 시퀀스 개수: 196793
# 시퀀스 개수: 196794
# 시퀀스 개수: 196795
# 시퀀스 개수: 196796
# 시퀀스 개수: 196797
# 시퀀스 개수: 196798
# 시퀀스 개수: 196799
# 시퀀스 개수: 196800
# 시퀀스 개수: 196801
# 시퀀스 개수: 196802
# 시퀀스 개수: 196803
# 시퀀스 개수: 196804
# 시퀀스 개수: 196805
# 시퀀스 개수: 196806
# 시퀀스 개수: 196807
# 시퀀스 개수: 196808
# 시퀀스 개수: 196809
# 시퀀스 개수: 196810
# 시퀀스 개수: 196811
# 시퀀스 개수: 196812
# 시퀀스 개수: 196813
# 시퀀스 개수: 196814
# 시퀀스 개수: 196815
# 시퀀스 개수: 196816
# 시퀀스 개수: 196817
# 시퀀스 개수: 196818
# 시퀀스 개수: 196819
# 시퀀스 개수: 196820
# 시퀀스 개수: 196821
# 시퀀스 개수: 196822
# 시퀀스 개수: 196823
# 시퀀스 개수: 196824
# 시퀀스 개수: 196825
# 시퀀스 개수: 196826
# 시퀀스 개수: 196827
# 시퀀스 개수: 196828
# 시퀀스 개수: 196829
# 시퀀스 개수: 196830
# 시퀀스 개수: 196831
# 시퀀스 개수: 196832
# 시퀀스 개수: 196833
# 시퀀스 개수: 196834
# 시퀀스 개수: 196835
# 시퀀스 개수: 196836
# 시퀀스 개수: 196837
# 시퀀스 개수: 196838
# 시퀀스 개수: 196839
# 시퀀스 개수: 196840
# 시퀀스 개수: 196841
# 시퀀스 개수: 196842
# 시퀀스 개수: 196843
# 시퀀스 개수: 196844
# 시퀀스 개수: 196845
# 시퀀스 개수: 196846
# 시퀀스 개수: 196847
# 시퀀스 개수: 196848
# 시퀀스 개수: 196849
# 시퀀스 개수: 196850
# 시퀀스 개수: 196851
# 시퀀스 개수: 196852
# 시퀀스 개수: 196853
# 시퀀스 개수: 196854
# 시퀀스 개수: 196855
# 시퀀스 개수: 196856
# 시퀀스 개수: 196857
# 시퀀스 개수: 196858
# 시퀀스 개수: 196859
# 시퀀스 개수: 196860
# 시퀀스 개수: 196861
# 시퀀스 개수: 196862
# 시퀀스 개수: 196863
# 시퀀스 개수: 196864
# 시퀀스 개수: 196865
# 시퀀스 개수: 196866
# 시퀀스 개수: 196867
# 시퀀스 개수: 196868
# 시퀀스 개수: 196869
# 시퀀스 개수: 196870
# 시퀀스 개수: 196871
# 시퀀스 개수: 196872
# 시퀀스 개수: 196873
# 시퀀스 개수: 196874
# 시퀀스 개수: 196875
# 시퀀스 개수: 196876
# 시퀀스 개수: 196877
# 시퀀스 개수: 196878
# 시퀀스 개수: 196879
# 시퀀스 개수: 196880
# 시퀀스 개수: 196881
# 시퀀스 개수: 196882
# 시퀀스 개수: 196883
# 시퀀스 개수: 196884
# 시퀀스 개수: 196885
# 시퀀스 개수: 196886
# 시퀀스 개수: 196887
# 시퀀스 개수: 196888
# 시퀀스 개수: 196889
# 시퀀스 개수: 196890
# 시퀀스 개수: 196891
# 시퀀스 개수: 196892
# 시퀀스 개수: 196893
# 시퀀스 개수: 196894
# 시퀀스 개수: 196895
# 시퀀스 개수: 196896
# 시퀀스 개수: 196897
# 시퀀스 개수: 196898
# 시퀀스 개수: 196899
# 시퀀스 개수: 196900
# 시퀀스 개수: 196901
# 시퀀스 개수: 196902
# 시퀀스 개수: 196903
# 시퀀스 개수: 196904
# 시퀀스 개수: 196905
# 시퀀스 개수: 196906
# 시퀀스 개수: 196907
# 시퀀스 개수: 196908
# 시퀀스 개수: 196909
# 시퀀스 개수: 196910
# 시퀀스 개수: 196911
# 시퀀스 개수: 196912
# 시퀀스 개수: 196913
# 시퀀스 개수: 196914
# 시퀀스 개수: 196915
# 시퀀스 개수: 196916
# 시퀀스 개수: 196917
# 시퀀스 개수: 196918
# 시퀀스 개수: 196919
# 시퀀스 개수: 196920
# 시퀀스 개수: 196921
# 시퀀스 개수: 196922
# 시퀀스 개수: 196923
# 시퀀스 개수: 196924
# 시퀀스 개수: 196925
# 시퀀스 개수: 196926
# 시퀀스 개수: 196927
# 시퀀스 개수: 196928
# 시퀀스 개수: 196929
# 시퀀스 개수: 196930
# 시퀀스 개수: 196931
# 시퀀스 개수: 196932
# 시퀀스 개수: 196933
# 시퀀스 개수: 196934
# 시퀀스 개수: 196935
# 시퀀스 개수: 196936
# 시퀀스 개수: 196937
# 시퀀스 개수: 196938
# 시퀀스 개수: 196939
# 시퀀스 개수: 196940
# 시퀀스 개수: 196941
# 시퀀스 개수: 196942
# 시퀀스 개수: 196943
# 시퀀스 개수: 196944
# 시퀀스 개수: 196945
# 시퀀스 개수: 196946
# 시퀀스 개수: 196947
# 시퀀스 개수: 196948
# 시퀀스 개수: 196949
# 시퀀스 개수: 196950
# 시퀀스 개수: 196951
# 시퀀스 개수: 196952
# 시퀀스 개수: 196953
# 시퀀스 개수: 196954
# 시퀀스 개수: 196955
# 시퀀스 개수: 196956
# 시퀀스 개수: 196957
# 시퀀스 개수: 196958
# 시퀀스 개수: 196959
# 시퀀스 개수: 196960
# 시퀀스 개수: 196961
# 시퀀스 개수: 196962
# 시퀀스 개수: 196963
# 시퀀스 개수: 196964
# 시퀀스 개수: 196965
# 시퀀스 개수: 196966
# 시퀀스 개수: 196967
# 시퀀스 개수: 196968
# 시퀀스 개수: 196969
# 시퀀스 개수: 196970
# 시퀀스 개수: 196971
# 시퀀스 개수: 196972
# 시퀀스 개수: 196973
# 시퀀스 개수: 196974
# 시퀀스 개수: 196975
# 시퀀스 개수: 196976
# 시퀀스 개수: 196977
# 시퀀스 개수: 196978
# 시퀀스 개수: 196979
# 시퀀스 개수: 196980
# 시퀀스 개수: 196981
# 시퀀스 개수: 196982
# 시퀀스 개수: 196983
# 시퀀스 개수: 196984
# 시퀀스 개수: 196985
# 시퀀스 개수: 196986
# 시퀀스 개수: 196987
# 시퀀스 개수: 196988
# 시퀀스 개수: 196989
# 시퀀스 개수: 196990
# 시퀀스 개수: 196991
# 시퀀스 개수: 196992
# 시퀀스 개수: 196993
# 시퀀스 개수: 196994
# 시퀀스 개수: 196995
# 시퀀스 개수: 196996
# 시퀀스 개수: 196997
# 시퀀스 개수: 196998
# 시퀀스 개수: 196999
# 시퀀스 개수: 197000
# 시퀀스 개수: 197001
# 시퀀스 개수: 197002
# 시퀀스 개수: 197003
# 시퀀스 개수: 197004
# 시퀀스 개수: 197005
# 시퀀스 개수: 197006
# 시퀀스 개수: 197007
# 시퀀스 개수: 197008
# 시퀀스 개수: 197009
# 시퀀스 개수: 197010
# 시퀀스 개수: 197011
# 시퀀스 개수: 197012
# 시퀀스 개수: 197013
# 시퀀스 개수: 197014
# 시퀀스 개수: 197015
# 시퀀스 개수: 197016
# 시퀀스 개수: 197017
# 시퀀스 개수: 197018
# 시퀀스 개수: 197019
# 시퀀스 개수: 197020
# 시퀀스 개수: 197021
# 시퀀스 개수: 197022
# 시퀀스 개수: 197023
# 시퀀스 개수: 197024
# 시퀀스 개수: 197025
# 시퀀스 개수: 197026
# 시퀀스 개수: 197027
# 시퀀스 개수: 197028
# 시퀀스 개수: 197029
# 시퀀스 개수: 197030
# 시퀀스 개수: 197031
# 시퀀스 개수: 197032
# 시퀀스 개수: 197033
# 시퀀스 개수: 197034
# 시퀀스 개수: 197035
# 시퀀스 개수: 197036
# 시퀀스 개수: 197037
# 시퀀스 개수: 197038
# 시퀀스 개수: 197039
# 시퀀스 개수: 197040
# 시퀀스 개수: 197041
# 시퀀스 개수: 197042
# 시퀀스 개수: 197043
# 시퀀스 개수: 197044
# 시퀀스 개수: 197045
# 시퀀스 개수: 197046
# 시퀀스 개수: 197047
# 시퀀스 개수: 197048
# 시퀀스 개수: 197049
# 시퀀스 개수: 197050
# 시퀀스 개수: 197051
# 시퀀스 개수: 197052
# 시퀀스 개수: 197053
# 시퀀스 개수: 197054
# 시퀀스 개수: 197055
# 시퀀스 개수: 197056
# 시퀀스 개수: 197057
# 시퀀스 개수: 197058
# 시퀀스 개수: 197059
# 시퀀스 개수: 197060
# 시퀀스 개수: 197061
# 시퀀스 개수: 197062
# 시퀀스 개수: 197063
# 시퀀스 개수: 197064
# 시퀀스 개수: 197065
# 시퀀스 개수: 197066
# 시퀀스 개수: 197067
# 시퀀스 개수: 197068
# 시퀀스 개수: 197069
# 시퀀스 개수: 197070
# 시퀀스 개수: 197071
# 시퀀스 개수: 197072
# 시퀀스 개수: 197073
# 시퀀스 개수: 197074
# 시퀀스 개수: 197075
# 시퀀스 개수: 197076
# 시퀀스 개수: 197077
# 시퀀스 개수: 197078
# 시퀀스 개수: 197079
# 시퀀스 개수: 197080
# 시퀀스 개수: 197081
# 시퀀스 개수: 197082
# 시퀀스 개수: 197083
# 시퀀스 개수: 197084
# 시퀀스 개수: 197085
# 시퀀스 개수: 197086
# 시퀀스 개수: 197087
# 시퀀스 개수: 197088
# 시퀀스 개수: 197089
# 시퀀스 개수: 197090
# 시퀀스 개수: 197091
# 시퀀스 개수: 197092
# 시퀀스 개수: 197093
# 시퀀스 개수: 197094
# 시퀀스 개수: 197095
# 시퀀스 개수: 197096
# 시퀀스 개수: 197097
# 시퀀스 개수: 197098
# 시퀀스 개수: 197099
# 시퀀스 개수: 197100
# 시퀀스 개수: 197101
# 시퀀스 개수: 197102
# 시퀀스 개수: 197103
# 시퀀스 개수: 197104
# 시퀀스 개수: 197105
# 시퀀스 개수: 197106
# 시퀀스 개수: 197107
# 시퀀스 개수: 197108
# 시퀀스 개수: 197109
# 시퀀스 개수: 197110
# 시퀀스 개수: 197111
# 시퀀스 개수: 197112
# 시퀀스 개수: 197113
# 시퀀스 개수: 197114
# 시퀀스 개수: 197115
# 시퀀스 개수: 197116
# 시퀀스 개수: 197117
# 시퀀스 개수: 197118
# 시퀀스 개수: 197119
# 시퀀스 개수: 197120
# 시퀀스 개수: 197121
# 시퀀스 개수: 197122
# 시퀀스 개수: 197123
# 시퀀스 개수: 197124
# 시퀀스 개수: 197125
# 시퀀스 개수: 197126
# 시퀀스 개수: 197127
# 시퀀스 개수: 197128
# 시퀀스 개수: 197129
# 시퀀스 개수: 197130
# 시퀀스 개수: 197131
# 시퀀스 개수: 197132
# 시퀀스 개수: 197133
# 시퀀스 개수: 197134
# 시퀀스 개수: 197135
# 시퀀스 개수: 197136
# 시퀀스 개수: 197137
# 시퀀스 개수: 197138
# 시퀀스 개수: 197139
# 시퀀스 개수: 197140
# 시퀀스 개수: 197141
# 시퀀스 개수: 197142
# 시퀀스 개수: 197143
# 시퀀스 개수: 197144
# 시퀀스 개수: 197145
# 시퀀스 개수: 197146
# 시퀀스 개수: 197147
# 시퀀스 개수: 197148
# 시퀀스 개수: 197149
# 시퀀스 개수: 197150
# 시퀀스 개수: 197151
# 시퀀스 개수: 197152
# 시퀀스 개수: 197153
# 시퀀스 개수: 197154
# 시퀀스 개수: 197155
# 시퀀스 개수: 197156
# 시퀀스 개수: 197157
# 시퀀스 개수: 197158
# 시퀀스 개수: 197159
# 시퀀스 개수: 197160
# 시퀀스 개수: 197161
# 시퀀스 개수: 197162
# 시퀀스 개수: 197163
# 시퀀스 개수: 197164
# 시퀀스 개수: 197165
# 시퀀스 개수: 197166
# 시퀀스 개수: 197167
# 시퀀스 개수: 197168
# 시퀀스 개수: 197169
# 시퀀스 개수: 197170
# 시퀀스 개수: 197171
# 시퀀스 개수: 197172
# 시퀀스 개수: 197173
# 시퀀스 개수: 197174
# 시퀀스 개수: 197175
# 시퀀스 개수: 197176
# 시퀀스 개수: 197177
# 시퀀스 개수: 197178
# 시퀀스 개수: 197179
# 시퀀스 개수: 197180
# 시퀀스 개수: 197181
# 시퀀스 개수: 197182
# 시퀀스 개수: 197183
# 시퀀스 개수: 197184
# 시퀀스 개수: 197185
# 시퀀스 개수: 197186
# 시퀀스 개수: 197187
# 시퀀스 개수: 197188
# 시퀀스 개수: 197189
# 시퀀스 개수: 197190
# 시퀀스 개수: 197191
# 시퀀스 개수: 197192
# 시퀀스 개수: 197193
# 시퀀스 개수: 197194
# 시퀀스 개수: 197195
# 시퀀스 개수: 197196
# 시퀀스 개수: 197197
# 시퀀스 개수: 197198
# 시퀀스 개수: 197199
# 시퀀스 개수: 197200
# 시퀀스 개수: 197201
# 시퀀스 개수: 197202
# 시퀀스 개수: 197203
# 시퀀스 개수: 197204
# 시퀀스 개수: 197205
# 시퀀스 개수: 197206
# 시퀀스 개수: 197207
# 시퀀스 개수: 197208
# 시퀀스 개수: 197209
# 시퀀스 개수: 197210
# 시퀀스 개수: 197211
# 시퀀스 개수: 197212
# 시퀀스 개수: 197213
# 시퀀스 개수: 197214
# 시퀀스 개수: 197215
# 시퀀스 개수: 197216
# 시퀀스 개수: 197217
# 시퀀스 개수: 197218
# 시퀀스 개수: 197219
# 시퀀스 개수: 197220
# 시퀀스 개수: 197221
# 시퀀스 개수: 197222
# 시퀀스 개수: 197223
# 시퀀스 개수: 197224
# 시퀀스 개수: 197225
# 시퀀스 개수: 197226
# 시퀀스 개수: 197227
# 시퀀스 개수: 197228
# 시퀀스 개수: 197229
# 시퀀스 개수: 197230
# 시퀀스 개수: 197231
# 시퀀스 개수: 197232
# 시퀀스 개수: 197233
# 시퀀스 개수: 197234
# 시퀀스 개수: 197235
# 시퀀스 개수: 197236
# 시퀀스 개수: 197237
# 시퀀스 개수: 197238
# 시퀀스 개수: 197239
# 시퀀스 개수: 197240
# 시퀀스 개수: 197241
# 시퀀스 개수: 197242
# 시퀀스 개수: 197243
# 시퀀스 개수: 197244
# 시퀀스 개수: 197245
# 시퀀스 개수: 197246
# 시퀀스 개수: 197247
# 시퀀스 개수: 197248
# 시퀀스 개수: 197249
# 시퀀스 개수: 197250
# 시퀀스 개수: 197251
# 시퀀스 개수: 197252
# 시퀀스 개수: 197253
# 시퀀스 개수: 197254
# 시퀀스 개수: 197255
# 시퀀스 개수: 197256
# 시퀀스 개수: 197257
# 시퀀스 개수: 197258
# 시퀀스 개수: 197259
# 시퀀스 개수: 197260
# 시퀀스 개수: 197261
# 시퀀스 개수: 197262
# 시퀀스 개수: 197263
# 시퀀스 개수: 197264
# 시퀀스 개수: 197265
# 시퀀스 개수: 197266
# 시퀀스 개수: 197267
# 시퀀스 개수: 197268
# 시퀀스 개수: 197269
# 시퀀스 개수: 197270
# 시퀀스 개수: 197271
# 시퀀스 개수: 197272
# 시퀀스 개수: 197273
# 시퀀스 개수: 197274
# 시퀀스 개수: 197275
# 시퀀스 개수: 197276
# 시퀀스 개수: 197277
# 시퀀스 개수: 197278
# 시퀀스 개수: 197279
# 시퀀스 개수: 197280
# 시퀀스 개수: 197281
# 시퀀스 개수: 197282
# 시퀀스 개수: 197283
# 시퀀스 개수: 197284
# 시퀀스 개수: 197285
# 시퀀스 개수: 197286
# 시퀀스 개수: 197287
# 시퀀스 개수: 197288
# 시퀀스 개수: 197289
# 시퀀스 개수: 197290
# 시퀀스 개수: 197291
# 시퀀스 개수: 197292
# 시퀀스 개수: 197293
# 시퀀스 개수: 197294
# 시퀀스 개수: 197295
# 시퀀스 개수: 197296
# 시퀀스 개수: 197297
# 시퀀스 개수: 197298
# 시퀀스 개수: 197299
# 시퀀스 개수: 197300
# 시퀀스 개수: 197301
# 시퀀스 개수: 197302
# 시퀀스 개수: 197303
# 시퀀스 개수: 197304
# 시퀀스 개수: 197305
# 시퀀스 개수: 197306
# 시퀀스 개수: 197307
# 시퀀스 개수: 197308
# 시퀀스 개수: 197309
# 시퀀스 개수: 197310
# 시퀀스 개수: 197311
# 시퀀스 개수: 197312
# 시퀀스 개수: 197313
# 시퀀스 개수: 197314
# 시퀀스 개수: 197315
# 시퀀스 개수: 197316
# 시퀀스 개수: 197317
# 시퀀스 개수: 197318
# 시퀀스 개수: 197319
# 시퀀스 개수: 197320
# 시퀀스 개수: 197321
# 시퀀스 개수: 197322
# 시퀀스 개수: 197323
# 시퀀스 개수: 197324
# 시퀀스 개수: 197325
# 시퀀스 개수: 197326
# 시퀀스 개수: 197327
# 시퀀스 개수: 197328
# 시퀀스 개수: 197329
# 시퀀스 개수: 197330
# 시퀀스 개수: 197331
# 시퀀스 개수: 197332
# 시퀀스 개수: 197333
# 시퀀스 개수: 197334
# 시퀀스 개수: 197335
# 시퀀스 개수: 197336
# 시퀀스 개수: 197337
# 시퀀스 개수: 197338
# 시퀀스 개수: 197339
# 시퀀스 개수: 197340
# 시퀀스 개수: 197341
# 시퀀스 개수: 197342
# 시퀀스 개수: 197343
# 시퀀스 개수: 197344
# 시퀀스 개수: 197345
# 시퀀스 개수: 197346
# 시퀀스 개수: 197347
# 시퀀스 개수: 197348
# 시퀀스 개수: 197349
# 시퀀스 개수: 197350
# 시퀀스 개수: 197351
# 시퀀스 개수: 197352
# 시퀀스 개수: 197353
# 시퀀스 개수: 197354
# 시퀀스 개수: 197355
# 시퀀스 개수: 197356
# 시퀀스 개수: 197357
# 시퀀스 개수: 197358
# 시퀀스 개수: 197359
# 시퀀스 개수: 197360
# 시퀀스 개수: 197361
# 시퀀스 개수: 197362
# 시퀀스 개수: 197363
# 시퀀스 개수: 197364
# 시퀀스 개수: 197365
# 시퀀스 개수: 197366
# 시퀀스 개수: 197367
# 시퀀스 개수: 197368
# 시퀀스 개수: 197369
# 시퀀스 개수: 197370
# 시퀀스 개수: 197371
# 시퀀스 개수: 197372
# 시퀀스 개수: 197373
# 시퀀스 개수: 197374
# 시퀀스 개수: 197375
# 시퀀스 개수: 197376
# 시퀀스 개수: 197377
# 시퀀스 개수: 197378
# 시퀀스 개수: 197379
# 시퀀스 개수: 197380
# 시퀀스 개수: 197381
# 시퀀스 개수: 197382
# 시퀀스 개수: 197383
# 시퀀스 개수: 197384
# 시퀀스 개수: 197385
# 시퀀스 개수: 197386
# 시퀀스 개수: 197387
# 시퀀스 개수: 197388
# 시퀀스 개수: 197389
# 시퀀스 개수: 197390
# 시퀀스 개수: 197391
# 시퀀스 개수: 197392
# 시퀀스 개수: 197393
# 시퀀스 개수: 197394
# 시퀀스 개수: 197395
# 시퀀스 개수: 197396
# 시퀀스 개수: 197397
# 시퀀스 개수: 197398
# 시퀀스 개수: 197399
# 시퀀스 개수: 197400
# 시퀀스 개수: 197401
# 시퀀스 개수: 197402
# 시퀀스 개수: 197403
# 시퀀스 개수: 197404
# 시퀀스 개수: 197405
# 시퀀스 개수: 197406
# 시퀀스 개수: 197407
# 시퀀스 개수: 197408
# 시퀀스 개수: 197409
# 시퀀스 개수: 197410
# 시퀀스 개수: 197411
# 시퀀스 개수: 197412
# 시퀀스 개수: 197413
# 시퀀스 개수: 197414
# 시퀀스 개수: 197415
# 시퀀스 개수: 197416
# 시퀀스 개수: 197417
# 시퀀스 개수: 197418
# 시퀀스 개수: 197419
# 시퀀스 개수: 197420
# 시퀀스 개수: 197421
# 시퀀스 개수: 197422
# 시퀀스 개수: 197423
# 시퀀스 개수: 197424
# 시퀀스 개수: 197425
# 시퀀스 개수: 197426
# 시퀀스 개수: 197427
# 시퀀스 개수: 197428
# 시퀀스 개수: 197429
# 시퀀스 개수: 197430
# 시퀀스 개수: 197431
# 시퀀스 개수: 197432
# 시퀀스 개수: 197433
# 시퀀스 개수: 197434
# 시퀀스 개수: 197435
# 시퀀스 개수: 197436
# 시퀀스 개수: 197437
# 시퀀스 개수: 197438
# 시퀀스 개수: 197439
# 시퀀스 개수: 197440
# 시퀀스 개수: 197441
# 시퀀스 개수: 197442
# 시퀀스 개수: 197443
# 시퀀스 개수: 197444
# 시퀀스 개수: 197445
# 시퀀스 개수: 197446
# 시퀀스 개수: 197447
# 시퀀스 개수: 197448
# 시퀀스 개수: 197449
# 시퀀스 개수: 197450
# 시퀀스 개수: 197451
# 시퀀스 개수: 197452
# 시퀀스 개수: 197453
# 시퀀스 개수: 197454
# 시퀀스 개수: 197455
# 시퀀스 개수: 197456
# 시퀀스 개수: 197457
# 시퀀스 개수: 197458
# 시퀀스 개수: 197459
# 시퀀스 개수: 197460
# 시퀀스 개수: 197461
# 시퀀스 개수: 197462
# 시퀀스 개수: 197463
# 시퀀스 개수: 197464
# 시퀀스 개수: 197465
# 시퀀스 개수: 197466
# 시퀀스 개수: 197467
# 시퀀스 개수: 197468
# 시퀀스 개수: 197469
# 시퀀스 개수: 197470
# 시퀀스 개수: 197471
# 시퀀스 개수: 197472
# 시퀀스 개수: 197473
# 시퀀스 개수: 197474
# 시퀀스 개수: 197475
# 시퀀스 개수: 197476
# 시퀀스 개수: 197477
# 시퀀스 개수: 197478
# 시퀀스 개수: 197479
# 시퀀스 개수: 197480
# 시퀀스 개수: 197481
# 시퀀스 개수: 197482
# 시퀀스 개수: 197483
# 시퀀스 개수: 197484
# 시퀀스 개수: 197485
# 시퀀스 개수: 197486
# 시퀀스 개수: 197487
# 시퀀스 개수: 197488
# 시퀀스 개수: 197489
# 시퀀스 개수: 197490
# 시퀀스 개수: 197491
# 시퀀스 개수: 197492
# 시퀀스 개수: 197493
# 시퀀스 개수: 197494
# 시퀀스 개수: 197495
# 시퀀스 개수: 197496
# 시퀀스 개수: 197497
# 시퀀스 개수: 197498
# 시퀀스 개수: 197499
# 시퀀스 개수: 197500
# 시퀀스 개수: 197501
# 시퀀스 개수: 197502
# 시퀀스 개수: 197503
# 시퀀스 개수: 197504
# 시퀀스 개수: 197505
# 시퀀스 개수: 197506
# 시퀀스 개수: 197507
# 시퀀스 개수: 197508
# 시퀀스 개수: 197509
# 시퀀스 개수: 197510
# 시퀀스 개수: 197511
# 시퀀스 개수: 197512
# 시퀀스 개수: 197513
# 시퀀스 개수: 197514
# 시퀀스 개수: 197515
# 시퀀스 개수: 197516
# 시퀀스 개수: 197517
# 시퀀스 개수: 197518
# 시퀀스 개수: 197519
# 시퀀스 개수: 197520
# 시퀀스 개수: 197521
# 시퀀스 개수: 197522
# 시퀀스 개수: 197523
# 시퀀스 개수: 197524
# 시퀀스 개수: 197525
# 시퀀스 개수: 197526
# 시퀀스 개수: 197527
# 시퀀스 개수: 197528
# 시퀀스 개수: 197529
# 시퀀스 개수: 197530
# 시퀀스 개수: 197531
# 시퀀스 개수: 197532
# 시퀀스 개수: 197533
# 시퀀스 개수: 197534
# 시퀀스 개수: 197535
# 시퀀스 개수: 197536
# 시퀀스 개수: 197537
# 시퀀스 개수: 197538
# 시퀀스 개수: 197539
# 시퀀스 개수: 197540
# 시퀀스 개수: 197541
# 시퀀스 개수: 197542
# 시퀀스 개수: 197543
# 시퀀스 개수: 197544
# 시퀀스 개수: 197545
# 시퀀스 개수: 197546
# 시퀀스 개수: 197547
# 시퀀스 개수: 197548
# 시퀀스 개수: 197549
# 시퀀스 개수: 197550
# 시퀀스 개수: 197551
# 시퀀스 개수: 197552
# 시퀀스 개수: 197553
# 시퀀스 개수: 197554
# 시퀀스 개수: 197555
# 시퀀스 개수: 197556
# 시퀀스 개수: 197557
# 시퀀스 개수: 197558
# 시퀀스 개수: 197559
# 시퀀스 개수: 197560
# 시퀀스 개수: 197561
# 시퀀스 개수: 197562
# 시퀀스 개수: 197563
# 시퀀스 개수: 197564
# 시퀀스 개수: 197565
# 시퀀스 개수: 197566
# 시퀀스 개수: 197567
# 시퀀스 개수: 197568
# 시퀀스 개수: 197569
# 시퀀스 개수: 197570
# 시퀀스 개수: 197571
# 시퀀스 개수: 197572
# 시퀀스 개수: 197573
# 시퀀스 개수: 197574
# 시퀀스 개수: 197575
# 시퀀스 개수: 197576
# 시퀀스 개수: 197577
# 시퀀스 개수: 197578
# 시퀀스 개수: 197579
# 시퀀스 개수: 197580
# 시퀀스 개수: 197581
# 시퀀스 개수: 197582
# 시퀀스 개수: 197583
# 시퀀스 개수: 197584
# 시퀀스 개수: 197585
# 시퀀스 개수: 197586
# 시퀀스 개수: 197587
# 시퀀스 개수: 197588
# 시퀀스 개수: 197589
# 시퀀스 개수: 197590
# 시퀀스 개수: 197591
# 시퀀스 개수: 197592
# 시퀀스 개수: 197593
# 시퀀스 개수: 197594
# 시퀀스 개수: 197595
# 시퀀스 개수: 197596
# 시퀀스 개수: 197597
# 시퀀스 개수: 197598
# 시퀀스 개수: 197599
# 시퀀스 개수: 197600
# 시퀀스 개수: 197601
# 시퀀스 개수: 197602
# 시퀀스 개수: 197603
# 시퀀스 개수: 197604
# 시퀀스 개수: 197605
# 시퀀스 개수: 197606
# 시퀀스 개수: 197607
# 시퀀스 개수: 197608
# 시퀀스 개수: 197609
# 시퀀스 개수: 197610
# 시퀀스 개수: 197611
# 시퀀스 개수: 197612
# 시퀀스 개수: 197613
# 시퀀스 개수: 197614
# 시퀀스 개수: 197615
# 시퀀스 개수: 197616
# 시퀀스 개수: 197617
# 시퀀스 개수: 197618
# 시퀀스 개수: 197619
# 시퀀스 개수: 197620
# 시퀀스 개수: 197621
# 시퀀스 개수: 197622
# 시퀀스 개수: 197623
# 시퀀스 개수: 197624
# 시퀀스 개수: 197625
# 시퀀스 개수: 197626
# 시퀀스 개수: 197627
# 시퀀스 개수: 197628
# 시퀀스 개수: 197629
# 시퀀스 개수: 197630
# 시퀀스 개수: 197631
# 시퀀스 개수: 197632
# 시퀀스 개수: 197633
# 시퀀스 개수: 197634
# 시퀀스 개수: 197635
# 시퀀스 개수: 197636
# 시퀀스 개수: 197637
# 시퀀스 개수: 197638
# 시퀀스 개수: 197639
# 시퀀스 개수: 197640
# 시퀀스 개수: 197641
# 시퀀스 개수: 197642
# 시퀀스 개수: 197643
# 시퀀스 개수: 197644
# 시퀀스 개수: 197645
# 시퀀스 개수: 197646
# 시퀀스 개수: 197647
# 시퀀스 개수: 197648
# 시퀀스 개수: 197649
# 시퀀스 개수: 197650
# 시퀀스 개수: 197651
# 시퀀스 개수: 197652
# 시퀀스 개수: 197653
# 시퀀스 개수: 197654
# 시퀀스 개수: 197655
# 시퀀스 개수: 197656
# 시퀀스 개수: 197657
# 시퀀스 개수: 197658
# 시퀀스 개수: 197659
# 시퀀스 개수: 197660
# 시퀀스 개수: 197661
# 시퀀스 개수: 197662
# 시퀀스 개수: 197663
# 시퀀스 개수: 197664
# 시퀀스 개수: 197665
# 시퀀스 개수: 197666
# 시퀀스 개수: 197667
# 시퀀스 개수: 197668
# 시퀀스 개수: 197669
# 시퀀스 개수: 197670
# 시퀀스 개수: 197671
# 시퀀스 개수: 197672
# 시퀀스 개수: 197673
# 시퀀스 개수: 197674
# 시퀀스 개수: 197675
# 시퀀스 개수: 197676
# 시퀀스 개수: 197677
# 시퀀스 개수: 197678
# 시퀀스 개수: 197679
# 시퀀스 개수: 197680
# 시퀀스 개수: 197681
# 시퀀스 개수: 197682
# 시퀀스 개수: 197683
# 시퀀스 개수: 197684
# 시퀀스 개수: 197685
# 시퀀스 개수: 197686
# 시퀀스 개수: 197687
# 시퀀스 개수: 197688
# 시퀀스 개수: 197689
# 시퀀스 개수: 197690
# 시퀀스 개수: 197691
# 시퀀스 개수: 197692
# 시퀀스 개수: 197693
# 시퀀스 개수: 197694
# 시퀀스 개수: 197695
# 시퀀스 개수: 197696
# 시퀀스 개수: 197697
# 시퀀스 개수: 197698
# 시퀀스 개수: 197699
# 시퀀스 개수: 197700
# 시퀀스 개수: 197701
# 시퀀스 개수: 197702
# 시퀀스 개수: 197703
# 시퀀스 개수: 197704
# 시퀀스 개수: 197705
# 시퀀스 개수: 197706
# 시퀀스 개수: 197707
# 시퀀스 개수: 197708
# 시퀀스 개수: 197709
# 시퀀스 개수: 197710
# 시퀀스 개수: 197711
# 시퀀스 개수: 197712
# 시퀀스 개수: 197713
# 시퀀스 개수: 197714
# 시퀀스 개수: 197715
# 시퀀스 개수: 197716
# 시퀀스 개수: 197717
# 시퀀스 개수: 197718
# 시퀀스 개수: 197719
# 시퀀스 개수: 197720
# 시퀀스 개수: 197721
# 시퀀스 개수: 197722
# 시퀀스 개수: 197723
# 시퀀스 개수: 197724
# 시퀀스 개수: 197725
# 시퀀스 개수: 197726
# 시퀀스 개수: 197727
# 시퀀스 개수: 197728
# 시퀀스 개수: 197729
# 시퀀스 개수: 197730
# 시퀀스 개수: 197731
# 시퀀스 개수: 197732
# 시퀀스 개수: 197733
# 시퀀스 개수: 197734
# 시퀀스 개수: 197735
# 시퀀스 개수: 197736
# 시퀀스 개수: 197737
# 시퀀스 개수: 197738
# 시퀀스 개수: 197739
# 시퀀스 개수: 197740
# 시퀀스 개수: 197741
# 시퀀스 개수: 197742
# 시퀀스 개수: 197743
# 시퀀스 개수: 197744
# 시퀀스 개수: 197745
# 시퀀스 개수: 197746
# 시퀀스 개수: 197747
# 시퀀스 개수: 197748
# 시퀀스 개수: 197749
# 시퀀스 개수: 197750
# 시퀀스 개수: 197751
# 시퀀스 개수: 197752
# 시퀀스 개수: 197753
# 시퀀스 개수: 197754
# 시퀀스 개수: 197755
# 시퀀스 개수: 197756
# 시퀀스 개수: 197757
# 시퀀스 개수: 197758
# 시퀀스 개수: 197759
# 시퀀스 개수: 197760
# 시퀀스 개수: 197761
# 시퀀스 개수: 197762
# 시퀀스 개수: 197763
# 시퀀스 개수: 197764
# 시퀀스 개수: 197765
# 시퀀스 개수: 197766
# 시퀀스 개수: 197767
# 시퀀스 개수: 197768
# 시퀀스 개수: 197769
# 시퀀스 개수: 197770
# 시퀀스 개수: 197771
# 시퀀스 개수: 197772
# 시퀀스 개수: 197773
# 시퀀스 개수: 197774
# 시퀀스 개수: 197775
# 시퀀스 개수: 197776
# 시퀀스 개수: 197777
# 시퀀스 개수: 197778
# 시퀀스 개수: 197779
# 시퀀스 개수: 197780
# 시퀀스 개수: 197781
# 시퀀스 개수: 197782
# 시퀀스 개수: 197783
# 시퀀스 개수: 197784
# 시퀀스 개수: 197785
# 시퀀스 개수: 197786
# 시퀀스 개수: 197787
# 시퀀스 개수: 197788
# 시퀀스 개수: 197789
# 시퀀스 개수: 197790
# 시퀀스 개수: 197791
# 시퀀스 개수: 197792
# 시퀀스 개수: 197793
# 시퀀스 개수: 197794
# 시퀀스 개수: 197795
# 시퀀스 개수: 197796
# 시퀀스 개수: 197797
# 시퀀스 개수: 197798
# 시퀀스 개수: 197799
# 시퀀스 개수: 197800
# 시퀀스 개수: 197801
# 시퀀스 개수: 197802
# 시퀀스 개수: 197803
# 시퀀스 개수: 197804
# 시퀀스 개수: 197805
# 시퀀스 개수: 197806
# 시퀀스 개수: 197807
# 시퀀스 개수: 197808
# 시퀀스 개수: 197809
# 시퀀스 개수: 197810
# 시퀀스 개수: 197811
# 시퀀스 개수: 197812
# 시퀀스 개수: 197813
# 시퀀스 개수: 197814
# 시퀀스 개수: 197815
# 시퀀스 개수: 197816
# 시퀀스 개수: 197817
# 시퀀스 개수: 197818
# 시퀀스 개수: 197819
# 시퀀스 개수: 197820
# 시퀀스 개수: 197821
# 시퀀스 개수: 197822
# 시퀀스 개수: 197823
# 시퀀스 개수: 197824
# 시퀀스 개수: 197825
# 시퀀스 개수: 197826
# 시퀀스 개수: 197827
# 시퀀스 개수: 197828
# 시퀀스 개수: 197829
# 시퀀스 개수: 197830
# 시퀀스 개수: 197831
# 시퀀스 개수: 197832
# 시퀀스 개수: 197833
# 시퀀스 개수: 197834
# 시퀀스 개수: 197835
# 시퀀스 개수: 197836
# 시퀀스 개수: 197837
# 시퀀스 개수: 197838
# 시퀀스 개수: 197839
# 시퀀스 개수: 197840
# 시퀀스 개수: 197841
# 시퀀스 개수: 197842
# 시퀀스 개수: 197843
# 시퀀스 개수: 197844
# 시퀀스 개수: 197845
# 시퀀스 개수: 197846
# 시퀀스 개수: 197847
# 시퀀스 개수: 197848
# 시퀀스 개수: 197849
# 시퀀스 개수: 197850
# 시퀀스 개수: 197851
# 시퀀스 개수: 197852
# 시퀀스 개수: 197853
# 시퀀스 개수: 197854
# 시퀀스 개수: 197855
# 시퀀스 개수: 197856
# 시퀀스 개수: 197857
# 시퀀스 개수: 197858
# 시퀀스 개수: 197859
# 시퀀스 개수: 197860
# 시퀀스 개수: 197861
# 시퀀스 개수: 197862
# 시퀀스 개수: 197863
# 시퀀스 개수: 197864
# 시퀀스 개수: 197865
# 시퀀스 개수: 197866
# 시퀀스 개수: 197867
# 시퀀스 개수: 197868
# 시퀀스 개수: 197869
# 시퀀스 개수: 197870
# 시퀀스 개수: 197871
# 시퀀스 개수: 197872
# 시퀀스 개수: 197873
# 시퀀스 개수: 197874
# 시퀀스 개수: 197875
# 시퀀스 개수: 197876
# 시퀀스 개수: 197877
# 시퀀스 개수: 197878
# 시퀀스 개수: 197879
# 시퀀스 개수: 197880
# 시퀀스 개수: 197881
# 시퀀스 개수: 197882
# 시퀀스 개수: 197883
# 시퀀스 개수: 197884
# 시퀀스 개수: 197885
# 시퀀스 개수: 197886
# 시퀀스 개수: 197887
# 시퀀스 개수: 197888
# 시퀀스 개수: 197889
# 시퀀스 개수: 197890
# 시퀀스 개수: 197891
# 시퀀스 개수: 197892
# 시퀀스 개수: 197893
# 시퀀스 개수: 197894
# 시퀀스 개수: 197895
# 시퀀스 개수: 197896
# 시퀀스 개수: 197897
# 시퀀스 개수: 197898
# 시퀀스 개수: 197899
# 시퀀스 개수: 197900
# 시퀀스 개수: 197901
# 시퀀스 개수: 197902
# 시퀀스 개수: 197903
# 시퀀스 개수: 197904
# 시퀀스 개수: 197905
# 시퀀스 개수: 197906
# 시퀀스 개수: 197907
# 시퀀스 개수: 197908
# 시퀀스 개수: 197909
# 시퀀스 개수: 197910
# 시퀀스 개수: 197911
# 시퀀스 개수: 197912
# 시퀀스 개수: 197913
# 시퀀스 개수: 197914
# 시퀀스 개수: 197915
# 시퀀스 개수: 197916
# 시퀀스 개수: 197917
# 시퀀스 개수: 197918
# 시퀀스 개수: 197919
# 시퀀스 개수: 197920
# 시퀀스 개수: 197921
# 시퀀스 개수: 197922
# 시퀀스 개수: 197923
# 시퀀스 개수: 197924
# 시퀀스 개수: 197925
# 시퀀스 개수: 197926
# 시퀀스 개수: 197927
# 시퀀스 개수: 197928
# 시퀀스 개수: 197929
# 시퀀스 개수: 197930
# 시퀀스 개수: 197931
# 시퀀스 개수: 197932
# 시퀀스 개수: 197933
# 시퀀스 개수: 197934
# 시퀀스 개수: 197935
# 시퀀스 개수: 197936
# 시퀀스 개수: 197937
# 시퀀스 개수: 197938
# 시퀀스 개수: 197939
# 시퀀스 개수: 197940
# 시퀀스 개수: 197941
# 시퀀스 개수: 197942
# 시퀀스 개수: 197943
# 시퀀스 개수: 197944
# 시퀀스 개수: 197945
# 시퀀스 개수: 197946
# 시퀀스 개수: 197947
# 시퀀스 개수: 197948
# 시퀀스 개수: 197949
# 시퀀스 개수: 197950
# 시퀀스 개수: 197951
# 시퀀스 개수: 197952
# 시퀀스 개수: 197953
# 시퀀스 개수: 197954
# 시퀀스 개수: 197955
# 시퀀스 개수: 197956
# 시퀀스 개수: 197957
# 시퀀스 개수: 197958
# 시퀀스 개수: 197959
# 시퀀스 개수: 197960
# 시퀀스 개수: 197961
# 시퀀스 개수: 197962
# 시퀀스 개수: 197963
# 시퀀스 개수: 197964
# 시퀀스 개수: 197965
# 시퀀스 개수: 197966
# 시퀀스 개수: 197967
# 시퀀스 개수: 197968
# 시퀀스 개수: 197969
# 시퀀스 개수: 197970
# 시퀀스 개수: 197971
# 시퀀스 개수: 197972
# 시퀀스 개수: 197973
# 시퀀스 개수: 197974
# 시퀀스 개수: 197975
# 시퀀스 개수: 197976
# 시퀀스 개수: 197977
# 시퀀스 개수: 197978
# 시퀀스 개수: 197979
# 시퀀스 개수: 197980
# 시퀀스 개수: 197981
# 시퀀스 개수: 197982
# 시퀀스 개수: 197983
# 시퀀스 개수: 197984
# 시퀀스 개수: 197985
# 시퀀스 개수: 197986
# 시퀀스 개수: 197987
# 시퀀스 개수: 197988
# 시퀀스 개수: 197989
# 시퀀스 개수: 197990
# 시퀀스 개수: 197991
# 시퀀스 개수: 197992
# 시퀀스 개수: 197993
# 시퀀스 개수: 197994
# 시퀀스 개수: 197995
# 시퀀스 개수: 197996
# 시퀀스 개수: 197997
# 시퀀스 개수: 197998
# 시퀀스 개수: 197999
# 시퀀스 개수: 198000
# 시퀀스 개수: 198001
# 시퀀스 개수: 198002
# 시퀀스 개수: 198003
# 시퀀스 개수: 198004
# 시퀀스 개수: 198005
# 시퀀스 개수: 198006
# 시퀀스 개수: 198007
# 시퀀스 개수: 198008
# 시퀀스 개수: 198009
# 시퀀스 개수: 198010
# 시퀀스 개수: 198011
# 시퀀스 개수: 198012
# 시퀀스 개수: 198013
# 시퀀스 개수: 198014
# 시퀀스 개수: 198015
# 시퀀스 개수: 198016
# 시퀀스 개수: 198017
# 시퀀스 개수: 198018
# 시퀀스 개수: 198019
# 시퀀스 개수: 198020
# 시퀀스 개수: 198021
# 시퀀스 개수: 198022
# 시퀀스 개수: 198023
# 시퀀스 개수: 198024
# 시퀀스 개수: 198025
# 시퀀스 개수: 198026
# 시퀀스 개수: 198027
# 시퀀스 개수: 198028
# 시퀀스 개수: 198029
# 시퀀스 개수: 198030
# 시퀀스 개수: 198031
# 시퀀스 개수: 198032
# 시퀀스 개수: 198033
# 시퀀스 개수: 198034
# 시퀀스 개수: 198035
# 시퀀스 개수: 198036
# 시퀀스 개수: 198037
# 시퀀스 개수: 198038
# 시퀀스 개수: 198039
# 시퀀스 개수: 198040
# 시퀀스 개수: 198041
# 시퀀스 개수: 198042
# 시퀀스 개수: 198043
# 시퀀스 개수: 198044
# 시퀀스 개수: 198045
# 시퀀스 개수: 198046
# 시퀀스 개수: 198047
# 시퀀스 개수: 198048
# 시퀀스 개수: 198049
# 시퀀스 개수: 198050
# 시퀀스 개수: 198051
# 시퀀스 개수: 198052
# 시퀀스 개수: 198053
# 시퀀스 개수: 198054
# 시퀀스 개수: 198055
# 시퀀스 개수: 198056
# 시퀀스 개수: 198057
# 시퀀스 개수: 198058
# 시퀀스 개수: 198059
# 시퀀스 개수: 198060
# 시퀀스 개수: 198061
# 시퀀스 개수: 198062
# 시퀀스 개수: 198063
# 시퀀스 개수: 198064
# 시퀀스 개수: 198065
# 시퀀스 개수: 198066
# 시퀀스 개수: 198067
# 시퀀스 개수: 198068
# 시퀀스 개수: 198069
# 시퀀스 개수: 198070
# 시퀀스 개수: 198071
# 시퀀스 개수: 198072
# 시퀀스 개수: 198073
# 시퀀스 개수: 198074
# 시퀀스 개수: 198075
# 시퀀스 개수: 198076
# 시퀀스 개수: 198077
# 시퀀스 개수: 198078
# 시퀀스 개수: 198079
# 시퀀스 개수: 198080
# 시퀀스 개수: 198081
# 시퀀스 개수: 198082
# 시퀀스 개수: 198083
# 시퀀스 개수: 198084
# 시퀀스 개수: 198085
# 시퀀스 개수: 198086
# 시퀀스 개수: 198087
# 시퀀스 개수: 198088
# 시퀀스 개수: 198089
# 시퀀스 개수: 198090
# 시퀀스 개수: 198091
# 시퀀스 개수: 198092
# 시퀀스 개수: 198093
# 시퀀스 개수: 198094
# 시퀀스 개수: 198095
# 시퀀스 개수: 198096
# 시퀀스 개수: 198097
# 시퀀스 개수: 198098
# 시퀀스 개수: 198099
# 시퀀스 개수: 198100
# 시퀀스 개수: 198101
# 시퀀스 개수: 198102
# 시퀀스 개수: 198103
# 시퀀스 개수: 198104
# 시퀀스 개수: 198105
# 시퀀스 개수: 198106
# 시퀀스 개수: 198107
# 시퀀스 개수: 198108
# 시퀀스 개수: 198109
# 시퀀스 개수: 198110
# 시퀀스 개수: 198111
# 시퀀스 개수: 198112
# 시퀀스 개수: 198113
# 시퀀스 개수: 198114
# 시퀀스 개수: 198115
# 시퀀스 개수: 198116
# 시퀀스 개수: 198117
# 시퀀스 개수: 198118
# 시퀀스 개수: 198119
# 시퀀스 개수: 198120
# 시퀀스 개수: 198121
# 시퀀스 개수: 198122
# 시퀀스 개수: 198123
# 시퀀스 개수: 198124
# 시퀀스 개수: 198125
# 시퀀스 개수: 198126
# 시퀀스 개수: 198127
# 시퀀스 개수: 198128
# 시퀀스 개수: 198129
# 시퀀스 개수: 198130
# 시퀀스 개수: 198131
# 시퀀스 개수: 198132
# 시퀀스 개수: 198133
# 시퀀스 개수: 198134
# 시퀀스 개수: 198135
# 시퀀스 개수: 198136
# 시퀀스 개수: 198137
# 시퀀스 개수: 198138
# 시퀀스 개수: 198139
# 시퀀스 개수: 198140
# 시퀀스 개수: 198141
# 시퀀스 개수: 198142
# 시퀀스 개수: 198143
# 시퀀스 개수: 198144
# 시퀀스 개수: 198145
# 시퀀스 개수: 198146
# 시퀀스 개수: 198147
# 시퀀스 개수: 198148
# 시퀀스 개수: 198149
# 시퀀스 개수: 198150
# 시퀀스 개수: 198151
# 시퀀스 개수: 198152
# 시퀀스 개수: 198153
# 시퀀스 개수: 198154
# 시퀀스 개수: 198155
# 시퀀스 개수: 198156
# 시퀀스 개수: 198157
# 시퀀스 개수: 198158
# 시퀀스 개수: 198159
# 시퀀스 개수: 198160
# 시퀀스 개수: 198161
# 시퀀스 개수: 198162
# 시퀀스 개수: 198163
# 시퀀스 개수: 198164
# 시퀀스 개수: 198165
# 시퀀스 개수: 198166
# 시퀀스 개수: 198167
# 시퀀스 개수: 198168
# 시퀀스 개수: 198169
# 시퀀스 개수: 198170
# 시퀀스 개수: 198171
# 시퀀스 개수: 198172
# 시퀀스 개수: 198173
# 시퀀스 개수: 198174
# 시퀀스 개수: 198175
# 시퀀스 개수: 198176
# 시퀀스 개수: 198177
# 시퀀스 개수: 198178
# 시퀀스 개수: 198179
# 시퀀스 개수: 198180
# 시퀀스 개수: 198181
# 시퀀스 개수: 198182
# 시퀀스 개수: 198183
# 시퀀스 개수: 198184
# 시퀀스 개수: 198185
# 시퀀스 개수: 198186
# 시퀀스 개수: 198187
# 시퀀스 개수: 198188
# 시퀀스 개수: 198189
# 시퀀스 개수: 198190
# 시퀀스 개수: 198191
# 시퀀스 개수: 198192
# 시퀀스 개수: 198193
# 시퀀스 개수: 198194
# 시퀀스 개수: 198195
# 시퀀스 개수: 198196
# 시퀀스 개수: 198197
# 시퀀스 개수: 198198
# 시퀀스 개수: 198199
# 시퀀스 개수: 198200
# 시퀀스 개수: 198201
# 시퀀스 개수: 198202
# 시퀀스 개수: 198203
# 시퀀스 개수: 198204
# 시퀀스 개수: 198205
# 시퀀스 개수: 198206
# 시퀀스 개수: 198207
# 시퀀스 개수: 198208
# 시퀀스 개수: 198209
# 시퀀스 개수: 198210
# 시퀀스 개수: 198211
# 시퀀스 개수: 198212
# 시퀀스 개수: 198213
# 시퀀스 개수: 198214
# 시퀀스 개수: 198215
# 시퀀스 개수: 198216
# 시퀀스 개수: 198217
# 시퀀스 개수: 198218
# 시퀀스 개수: 198219
# 시퀀스 개수: 198220
# 시퀀스 개수: 198221
# 시퀀스 개수: 198222
# 시퀀스 개수: 198223
# 시퀀스 개수: 198224
# 시퀀스 개수: 198225
# 시퀀스 개수: 198226
# 시퀀스 개수: 198227
# 시퀀스 개수: 198228
# 시퀀스 개수: 198229
# 시퀀스 개수: 198230
# 시퀀스 개수: 198231
# 시퀀스 개수: 198232
# 시퀀스 개수: 198233
# 시퀀스 개수: 198234
# 시퀀스 개수: 198235
# 시퀀스 개수: 198236
# 시퀀스 개수: 198237
# 시퀀스 개수: 198238
# 시퀀스 개수: 198239
# 시퀀스 개수: 198240
# 시퀀스 개수: 198241
# 시퀀스 개수: 198242
# 시퀀스 개수: 198243
# 시퀀스 개수: 198244
# 시퀀스 개수: 198245
# 시퀀스 개수: 198246
# 시퀀스 개수: 198247
# 시퀀스 개수: 198248
# 시퀀스 개수: 198249
# 시퀀스 개수: 198250
# 시퀀스 개수: 198251
# 시퀀스 개수: 198252
# 시퀀스 개수: 198253
# 시퀀스 개수: 198254
# 시퀀스 개수: 198255
# 시퀀스 개수: 198256
# 시퀀스 개수: 198257
# 시퀀스 개수: 198258
# 시퀀스 개수: 198259
# 시퀀스 개수: 198260
# 시퀀스 개수: 198261
# 시퀀스 개수: 198262
# 시퀀스 개수: 198263
# 시퀀스 개수: 198264
# 시퀀스 개수: 198265
# 시퀀스 개수: 198266
# 시퀀스 개수: 198267
# 시퀀스 개수: 198268
# 시퀀스 개수: 198269
# 시퀀스 개수: 198270
# 시퀀스 개수: 198271
# 시퀀스 개수: 198272
# 시퀀스 개수: 198273
# 시퀀스 개수: 198274
# 시퀀스 개수: 198275
# 시퀀스 개수: 198276
# 시퀀스 개수: 198277
# 시퀀스 개수: 198278
# 시퀀스 개수: 198279
# 시퀀스 개수: 198280
# 시퀀스 개수: 198281
# 시퀀스 개수: 198282
# 시퀀스 개수: 198283
# 시퀀스 개수: 198284
# 시퀀스 개수: 198285
# 시퀀스 개수: 198286
# 시퀀스 개수: 198287
# 시퀀스 개수: 198288
# 시퀀스 개수: 198289
# 시퀀스 개수: 198290
# 시퀀스 개수: 198291
# 시퀀스 개수: 198292
# 시퀀스 개수: 198293
# 시퀀스 개수: 198294
# 시퀀스 개수: 198295
# 시퀀스 개수: 198296
# 시퀀스 개수: 198297
# 시퀀스 개수: 198298
# 시퀀스 개수: 198299
# 시퀀스 개수: 198300
# 시퀀스 개수: 198301
# 시퀀스 개수: 198302
# 시퀀스 개수: 198303
# 시퀀스 개수: 198304
# 시퀀스 개수: 198305
# 시퀀스 개수: 198306
# 시퀀스 개수: 198307
# 시퀀스 개수: 198308
# 시퀀스 개수: 198309
# 시퀀스 개수: 198310
# 시퀀스 개수: 198311
# 시퀀스 개수: 198312
# 시퀀스 개수: 198313
# 시퀀스 개수: 198314
# 시퀀스 개수: 198315
# 시퀀스 개수: 198316
# 시퀀스 개수: 198317
# 시퀀스 개수: 198318
# 시퀀스 개수: 198319
# 시퀀스 개수: 198320
# 시퀀스 개수: 198321
# 시퀀스 개수: 198322
# 시퀀스 개수: 198323
# 시퀀스 개수: 198324
# 시퀀스 개수: 198325
# 시퀀스 개수: 198326
# 시퀀스 개수: 198327
# 시퀀스 개수: 198328
# 시퀀스 개수: 198329
# 시퀀스 개수: 198330
# 시퀀스 개수: 198331
# 시퀀스 개수: 198332
# 시퀀스 개수: 198333
# 시퀀스 개수: 198334
# 시퀀스 개수: 198335
# 시퀀스 개수: 198336
# 시퀀스 개수: 198337
# 시퀀스 개수: 198338
# 시퀀스 개수: 198339
# 시퀀스 개수: 198340
# 시퀀스 개수: 198341
# 시퀀스 개수: 198342
# 시퀀스 개수: 198343
# 시퀀스 개수: 198344
# 시퀀스 개수: 198345
# 시퀀스 개수: 198346
# 시퀀스 개수: 198347
# 시퀀스 개수: 198348
# 시퀀스 개수: 198349
# 시퀀스 개수: 198350
# 시퀀스 개수: 198351
# 시퀀스 개수: 198352
# 시퀀스 개수: 198353
# 시퀀스 개수: 198354
# 시퀀스 개수: 198355
# 시퀀스 개수: 198356
# 시퀀스 개수: 198357
# 시퀀스 개수: 198358
# 시퀀스 개수: 198359
# 시퀀스 개수: 198360
# 시퀀스 개수: 198361
# 시퀀스 개수: 198362
# 시퀀스 개수: 198363
# 시퀀스 개수: 198364
# 시퀀스 개수: 198365
# 시퀀스 개수: 198366
# 시퀀스 개수: 198367
# 시퀀스 개수: 198368
# 시퀀스 개수: 198369
# 시퀀스 개수: 198370
# 시퀀스 개수: 198371
# 시퀀스 개수: 198372
# 시퀀스 개수: 198373
# 시퀀스 개수: 198374
# 시퀀스 개수: 198375
# 시퀀스 개수: 198376
# 시퀀스 개수: 198377
# 시퀀스 개수: 198378
# 시퀀스 개수: 198379
# 시퀀스 개수: 198380
# 시퀀스 개수: 198381
# 시퀀스 개수: 198382
# 시퀀스 개수: 198383
# 시퀀스 개수: 198384
# 시퀀스 개수: 198385
# 시퀀스 개수: 198386
# 시퀀스 개수: 198387
# 시퀀스 개수: 198388
# 시퀀스 개수: 198389
# 시퀀스 개수: 198390
# 시퀀스 개수: 198391
# 시퀀스 개수: 198392
# 시퀀스 개수: 198393
# 시퀀스 개수: 198394
# 시퀀스 개수: 198395
# 시퀀스 개수: 198396
# 시퀀스 개수: 198397
# 시퀀스 개수: 198398
# 시퀀스 개수: 198399
# 시퀀스 개수: 198400
# 시퀀스 개수: 198401
# 시퀀스 개수: 198402
# 시퀀스 개수: 198403
# 시퀀스 개수: 198404
# 시퀀스 개수: 198405
# 시퀀스 개수: 198406
# 시퀀스 개수: 198407
# 시퀀스 개수: 198408
# 시퀀스 개수: 198409
# 시퀀스 개수: 198410
# 시퀀스 개수: 198411
# 시퀀스 개수: 198412
# 시퀀스 개수: 198413
# 시퀀스 개수: 198414
# 시퀀스 개수: 198415
# 시퀀스 개수: 198416
# 시퀀스 개수: 198417
# 시퀀스 개수: 198418
# 시퀀스 개수: 198419
# 시퀀스 개수: 198420
# 시퀀스 개수: 198421
# 시퀀스 개수: 198422
# 시퀀스 개수: 198423
# 시퀀스 개수: 198424
# 시퀀스 개수: 198425
# 시퀀스 개수: 198426
# 시퀀스 개수: 198427
# 시퀀스 개수: 198428
# 시퀀스 개수: 198429
# 시퀀스 개수: 198430
# 시퀀스 개수: 198431
# 시퀀스 개수: 198432
# 시퀀스 개수: 198433
# 시퀀스 개수: 198434
# 시퀀스 개수: 198435
# 시퀀스 개수: 198436
# 시퀀스 개수: 198437
# 시퀀스 개수: 198438
# 시퀀스 개수: 198439
# 시퀀스 개수: 198440
# 시퀀스 개수: 198441
# 시퀀스 개수: 198442
# 시퀀스 개수: 198443
# 시퀀스 개수: 198444
# 시퀀스 개수: 198445
# 시퀀스 개수: 198446
# 시퀀스 개수: 198447
# 시퀀스 개수: 198448
# 시퀀스 개수: 198449
# 시퀀스 개수: 198450
# 시퀀스 개수: 198451
# 시퀀스 개수: 198452
# 시퀀스 개수: 198453
# 시퀀스 개수: 198454
# 시퀀스 개수: 198455
# 시퀀스 개수: 198456
# 시퀀스 개수: 198457
# 시퀀스 개수: 198458
# 시퀀스 개수: 198459
# 시퀀스 개수: 198460
# 시퀀스 개수: 198461
# 시퀀스 개수: 198462
# 시퀀스 개수: 198463
# 시퀀스 개수: 198464
# 시퀀스 개수: 198465
# 시퀀스 개수: 198466
# 시퀀스 개수: 198467
# 시퀀스 개수: 198468
# 시퀀스 개수: 198469
# 시퀀스 개수: 198470
# 시퀀스 개수: 198471
# 시퀀스 개수: 198472
# 시퀀스 개수: 198473
# 시퀀스 개수: 198474
# 시퀀스 개수: 198475
# ...
# 시퀀스 개수: 199213
# 시퀀스 개수: 199214
# 시퀀스 개수: 199215
# 시퀀스 개수: 199216
# 시퀀스 개수: 199217
# 시퀀스 개수: 199218
# 시퀀스 개수: 199219
# 시퀀스 개수: 199220
# 시퀀스 개수: 199221
# 시퀀스 개수: 199222
# 시퀀스 개수: 199223
# 시퀀스 개수: 199224
# 시퀀스 개수: 199225
# 시퀀스 개수: 199226
# 시퀀스 개수: 199227
# 시퀀스 개수: 199228
# 시퀀스 개수: 199229
# 시퀀스 개수: 199230
# 시퀀스 개수: 199231
# 시퀀스 개수: 199232
# 시퀀스 개수: 199233
# 시퀀스 개수: 199234
# 시퀀스 개수: 199235
# 시퀀스 개수: 199236
# 시퀀스 개수: 199237
# 시퀀스 개수: 199238
# 시퀀스 개수: 199239
# 시퀀스 개수: 199240
# 시퀀스 개수: 199241
# 시퀀스 개수: 199242
# 시퀀스 개수: 199243
# 시퀀스 개수: 199244
# 시퀀스 개수: 199245
# 시퀀스 개수: 199246
# 시퀀스 개수: 199247
# 시퀀스 개수: 199248
# 시퀀스 개수: 199249
# 시퀀스 개수: 199250
# 시퀀스 개수: 199251
# 시퀀스 개수: 199252
# 시퀀스 개수: 199253
# 시퀀스 개수: 199254
# 시퀀스 개수: 199255
# 시퀀스 개수: 199256
# 시퀀스 개수: 199257
# 시퀀스 개수: 199258
# 시퀀스 개수: 199259
# 시퀀스 개수: 199260
# 시퀀스 개수: 199261
# 시퀀스 개수: 199262
# 시퀀스 개수: 199263
# 시퀀스 개수: 199264
# 시퀀스 개수: 199265
# 시퀀스 개수: 199266
# 시퀀스 개수: 199267
# 시퀀스 개수: 199268
# 시퀀스 개수: 199269
# 시퀀스 개수: 199270
# 시퀀스 개수: 199271
# 시퀀스 개수: 199272
# 시퀀스 개수: 199273
# 시퀀스 개수: 199274
# 시퀀스 개수: 199275
# 시퀀스 개수: 199276
# 시퀀스 개수: 199277
# 시퀀스 개수: 199278
# 시퀀스 개수: 199279
# 시퀀스 개수: 199280
# 시퀀스 개수: 199281
# 시퀀스 개수: 199282
# 시퀀스 개수: 199283
# 시퀀스 개수: 199284
# 시퀀스 개수: 199285
# 시퀀스 개수: 199286
# 시퀀스 개수: 199287
# 시퀀스 개수: 199288
# 시퀀스 개수: 199289
# 시퀀스 개수: 199290
# 시퀀스 개수: 199291
# 시퀀스 개수: 199292
# 시퀀스 개수: 199293
# 시퀀스 개수: 199294
# 시퀀스 개수: 199295
# 시퀀스 개수: 199296
# 시퀀스 개수: 199297
# 시퀀스 개수: 199298
# 시퀀스 개수: 199299
# 시퀀스 개수: 199300
# 시퀀스 개수: 199301
# 시퀀스 개수: 199302
# 시퀀스 개수: 199303
# 시퀀스 개수: 199304
# 시퀀스 개수: 199305
# 시퀀스 개수: 199306
# 시퀀스 개수: 199307
# 시퀀스 개수: 199308
# 시퀀스 개수: 199309
# 시퀀스 개수: 199310
# 시퀀스 개수: 199311
# 시퀀스 개수: 199312
# 시퀀스 개수: 199313
# 시퀀스 개수: 199314
# 시퀀스 개수: 199315
# 시퀀스 개수: 199316
# 시퀀스 개수: 199317
# 시퀀스 개수: 199318
# 시퀀스 개수: 199319
# 시퀀스 개수: 199320
# 시퀀스 개수: 199321
# 시퀀스 개수: 199322
# 시퀀스 개수: 199323
# 시퀀스 개수: 199324
# 시퀀스 개수: 199325
# 시퀀스 개수: 199326
# 시퀀스 개수: 199327
# 시퀀스 개수: 199328
# 시퀀스 개수: 199329
# 시퀀스 개수: 199330
# 시퀀스 개수: 199331
# 시퀀스 개수: 199332
# 시퀀스 개수: 199333
# 시퀀스 개수: 199334
# 시퀀스 개수: 199335
# 시퀀스 개수: 199336
# 시퀀스 개수: 199337
# 시퀀스 개수: 199338
# 시퀀스 개수: 199339
# 시퀀스 개수: 199340
# 시퀀스 개수: 199341
# 시퀀스 개수: 199342
# 시퀀스 개수: 199343
# 시퀀스 개수: 199344
# 시퀀스 개수: 199345
# 시퀀스 개수: 199346
# 시퀀스 개수: 199347
# 시퀀스 개수: 199348
# 시퀀스 개수: 199349
# 시퀀스 개수: 199350
# 시퀀스 개수: 199351
# 시퀀스 개수: 199352
# 시퀀스 개수: 199353
# 시퀀스 개수: 199354
# 시퀀스 개수: 199355
# 시퀀스 개수: 199356
# 시퀀스 개수: 199357
# 시퀀스 개수: 199358
# 시퀀스 개수: 199359
# 시퀀스 개수: 199360
# 시퀀스 개수: 199361
# 시퀀스 개수: 199362
# 시퀀스 개수: 199363
# 시퀀스 개수: 199364
# 시퀀스 개수: 199365
# 시퀀스 개수: 199366
# 시퀀스 개수: 199367
# 시퀀스 개수: 199368
# 시퀀스 개수: 199369
# 시퀀스 개수: 199370
# 시퀀스 개수: 199371
# 시퀀스 개수: 199372
# 시퀀스 개수: 199373
# 시퀀스 개수: 199374
# 시퀀스 개수: 199375
# 시퀀스 개수: 199376
# 시퀀스 개수: 199377
# 시퀀스 개수: 199378
# 시퀀스 개수: 199379
# 시퀀스 개수: 199380
# 시퀀스 개수: 199381
# 시퀀스 개수: 199382
# 시퀀스 개수: 199383
# 시퀀스 개수: 199384
# 시퀀스 개수: 199385
# 시퀀스 개수: 199386
# 시퀀스 개수: 199387
# 시퀀스 개수: 199388
# 시퀀스 개수: 199389
# 시퀀스 개수: 199390
# 시퀀스 개수: 199391
# 시퀀스 개수: 199392
# 시퀀스 개수: 199393
# 시퀀스 개수: 199394
# 시퀀스 개수: 199395
# 시퀀스 개수: 199396
# 시퀀스 개수: 199397
# 시퀀스 개수: 199398
# 시퀀스 개수: 199399
# 시퀀스 개수: 199400
# 시퀀스 개수: 199401
# 시퀀스 개수: 199402
# 시퀀스 개수: 199403
# 시퀀스 개수: 199404
# 시퀀스 개수: 199405
# 시퀀스 개수: 199406
# 시퀀스 개수: 199407
# 시퀀스 개수: 199408
# 시퀀스 개수: 199409
# 시퀀스 개수: 199410
# 시퀀스 개수: 199411
# 시퀀스 개수: 199412
# 시퀀스 개수: 199413
# 시퀀스 개수: 199414
# 시퀀스 개수: 199415
# 시퀀스 개수: 199416
# 시퀀스 개수: 199417
# 시퀀스 개수: 199418
# 시퀀스 개수: 199419
# 시퀀스 개수: 199420
# 시퀀스 개수: 199421
# 시퀀스 개수: 199422
# 시퀀스 개수: 199423
# 시퀀스 개수: 199424
# 시퀀스 개수: 199425
# 시퀀스 개수: 199426
# 시퀀스 개수: 199427
# 시퀀스 개수: 199428
# 시퀀스 개수: 199429
# 시퀀스 개수: 199430
# 시퀀스 개수: 199431
# 시퀀스 개수: 199432
# 시퀀스 개수: 199433
# 시퀀스 개수: 199434
# 시퀀스 개수: 199435
# 시퀀스 개수: 199436
# 시퀀스 개수: 199437
# 시퀀스 개수: 199438
# 시퀀스 개수: 199439
# 시퀀스 개수: 199440
# 시퀀스 개수: 199441
# 시퀀스 개수: 199442
# 시퀀스 개수: 199443
# 시퀀스 개수: 199444
# 시퀀스 개수: 199445
# 시퀀스 개수: 199446
# 시퀀스 개수: 199447
# 시퀀스 개수: 199448
# 시퀀스 개수: 199449
# 시퀀스 개수: 199450
# 시퀀스 개수: 199451
# 시퀀스 개수: 199452
# 시퀀스 개수: 199453
# 시퀀스 개수: 199454
# 시퀀스 개수: 199455
# 시퀀스 개수: 199456
# 시퀀스 개수: 199457
# 시퀀스 개수: 199458
# 시퀀스 개수: 199459
# 시퀀스 개수: 199460
# 시퀀스 개수: 199461
# 시퀀스 개수: 199462
# 시퀀스 개수: 199463
# 시퀀스 개수: 199464
# 시퀀스 개수: 199465
# 시퀀스 개수: 199466
# 시퀀스 개수: 199467
# 시퀀스 개수: 199468
# 시퀀스 개수: 199469
# 시퀀스 개수: 199470
# 시퀀스 개수: 199471
# 시퀀스 개수: 199472
# 시퀀스 개수: 199473
# 시퀀스 개수: 199474
# 시퀀스 개수: 199475
# 시퀀스 개수: 199476
# 시퀀스 개수: 199477
# 시퀀스 개수: 199478
# 시퀀스 개수: 199479
# 시퀀스 개수: 199480
# 시퀀스 개수: 199481
# 시퀀스 개수: 199482
# 시퀀스 개수: 199483
# 시퀀스 개수: 199484
# 시퀀스 개수: 199485
# 시퀀스 개수: 199486
# 시퀀스 개수: 199487
# 시퀀스 개수: 199488
# 시퀀스 개수: 199489
# 시퀀스 개수: 199490
# 시퀀스 개수: 199491
# 시퀀스 개수: 199492
# 시퀀스 개수: 199493
# 시퀀스 개수: 199494
# 시퀀스 개수: 199495
# 시퀀스 개수: 199496
# 시퀀스 개수: 199497
# 시퀀스 개수: 199498
# 시퀀스 개수: 199499
# 시퀀스 개수: 199500
# 시퀀스 개수: 199501
# 시퀀스 개수: 199502
# 시퀀스 개수: 199503
# 시퀀스 개수: 199504
# 시퀀스 개수: 199505
# 시퀀스 개수: 199506
# 시퀀스 개수: 199507
# 시퀀스 개수: 199508
# 시퀀스 개수: 199509
# 시퀀스 개수: 199510
# 시퀀스 개수: 199511
# 시퀀스 개수: 199512
# 시퀀스 개수: 199513
# 시퀀스 개수: 199514
# 시퀀스 개수: 199515
# 시퀀스 개수: 199516
# 시퀀스 개수: 199517
# 시퀀스 개수: 199518
# 시퀀스 개수: 199519
# 시퀀스 개수: 199520
# 시퀀스 개수: 199521
# 시퀀스 개수: 199522
# 시퀀스 개수: 199523
# 시퀀스 개수: 199524
# 시퀀스 개수: 199525
# 시퀀스 개수: 199526
# 시퀀스 개수: 199527
# 시퀀스 개수: 199528
# 시퀀스 개수: 199529
# 시퀀스 개수: 199530
# 시퀀스 개수: 199531
# 시퀀스 개수: 199532
# 시퀀스 개수: 199533
# 시퀀스 개수: 199534
# 시퀀스 개수: 199535
# 시퀀스 개수: 199536
# 시퀀스 개수: 199537
# 시퀀스 개수: 199538
# 시퀀스 개수: 199539
# 시퀀스 개수: 199540
# 시퀀스 개수: 199541
# 시퀀스 개수: 199542
# 시퀀스 개수: 199543
# 시퀀스 개수: 199544
# 시퀀스 개수: 199545
# 시퀀스 개수: 199546
# 시퀀스 개수: 199547
# 시퀀스 개수: 199548
# 시퀀스 개수: 199549
# 시퀀스 개수: 199550
# 시퀀스 개수: 199551
# 시퀀스 개수: 199552
# 시퀀스 개수: 199553
# 시퀀스 개수: 199554
# 시퀀스 개수: 199555
# 시퀀스 개수: 199556
# 시퀀스 개수: 199557
# 시퀀스 개수: 199558
# 시퀀스 개수: 199559
# 시퀀스 개수: 199560
# 시퀀스 개수: 199561
# 시퀀스 개수: 199562
# 시퀀스 개수: 199563
# 시퀀스 개수: 199564
# 시퀀스 개수: 199565
# 시퀀스 개수: 199566
# 시퀀스 개수: 199567
# 시퀀스 개수: 199568
# 시퀀스 개수: 199569
# 시퀀스 개수: 199570
# 시퀀스 개수: 199571
# 시퀀스 개수: 199572
# 시퀀스 개수: 199573
# 시퀀스 개수: 199574
# 시퀀스 개수: 199575
# 시퀀스 개수: 199576
# 시퀀스 개수: 199577
# 시퀀스 개수: 199578
# 시퀀스 개수: 199579
# 시퀀스 개수: 199580
# 시퀀스 개수: 199581
# 시퀀스 개수: 199582
# 시퀀스 개수: 199583
# 시퀀스 개수: 199584
# 시퀀스 개수: 199585
# 시퀀스 개수: 199586
# 시퀀스 개수: 199587
# 시퀀스 개수: 199588
# 시퀀스 개수: 199589
# 시퀀스 개수: 199590
# 시퀀스 개수: 199591
# 시퀀스 개수: 199592
# 시퀀스 개수: 199593
# 시퀀스 개수: 199594
# 시퀀스 개수: 199595
# 시퀀스 개수: 199596
# 시퀀스 개수: 199597
# 시퀀스 개수: 199598
# 시퀀스 개수: 199599
# 시퀀스 개수: 199600
# 시퀀스 개수: 199601
# 시퀀스 개수: 199602
# 시퀀스 개수: 199603
# 시퀀스 개수: 199604
# 시퀀스 개수: 199605
# 시퀀스 개수: 199606
# 시퀀스 개수: 199607
# 시퀀스 개수: 199608
# 시퀀스 개수: 199609
# 시퀀스 개수: 199610
# 시퀀스 개수: 199611
# 시퀀스 개수: 199612
# 시퀀스 개수: 199613
# 시퀀스 개수: 199614
# 시퀀스 개수: 199615
# 시퀀스 개수: 199616
# 시퀀스 개수: 199617
# 시퀀스 개수: 199618
# 시퀀스 개수: 199619
# 시퀀스 개수: 199620
# 시퀀스 개수: 199621
# 시퀀스 개수: 199622
# 시퀀스 개수: 199623
# 시퀀스 개수: 199624
# 시퀀스 개수: 199625
# 시퀀스 개수: 199626
# 시퀀스 개수: 199627
# 시퀀스 개수: 199628
# 시퀀스 개수: 199629
# 시퀀스 개수: 199630
# 시퀀스 개수: 199631
# 시퀀스 개수: 199632
# 시퀀스 개수: 199633
# 시퀀스 개수: 199634
# 시퀀스 개수: 199635
# 시퀀스 개수: 199636
# 시퀀스 개수: 199637
# 시퀀스 개수: 199638
# 시퀀스 개수: 199639
# 시퀀스 개수: 199640
# 시퀀스 개수: 199641
# 시퀀스 개수: 199642
# 시퀀스 개수: 199643
# 시퀀스 개수: 199644
# 시퀀스 개수: 199645
# 시퀀스 개수: 199646
# 시퀀스 개수: 199647
# 시퀀스 개수: 199648
# 시퀀스 개수: 199649
# 시퀀스 개수: 199650
# 시퀀스 개수: 199651
# 시퀀스 개수: 199652
# 시퀀스 개수: 199653
# 시퀀스 개수: 199654
# 시퀀스 개수: 199655
# 시퀀스 개수: 199656
# 시퀀스 개수: 199657
# 시퀀스 개수: 199658
# 시퀀스 개수: 199659
# 시퀀스 개수: 199660
# 시퀀스 개수: 199661
# 시퀀스 개수: 199662
# 시퀀스 개수: 199663
# 시퀀스 개수: 199664
# 시퀀스 개수: 199665
# 시퀀스 개수: 199666
# 시퀀스 개수: 199667
# 시퀀스 개수: 199668
# 시퀀스 개수: 199669
# 시퀀스 개수: 199670
# 시퀀스 개수: 199671
# 시퀀스 개수: 199672
# 시퀀스 개수: 199673
# 시퀀스 개수: 199674
# 시퀀스 개수: 199675
# 시퀀스 개수: 199676
# 시퀀스 개수: 199677
# 시퀀스 개수: 199678
# 시퀀스 개수: 199679
# 시퀀스 개수: 199680
# 시퀀스 개수: 199681
# 시퀀스 개수: 199682
# 시퀀스 개수: 199683
# 시퀀스 개수: 199684
# 시퀀스 개수: 199685
# 시퀀스 개수: 199686
# 시퀀스 개수: 199687
# 시퀀스 개수: 199688
# 시퀀스 개수: 199689
# 시퀀스 개수: 199690
# 시퀀스 개수: 199691
# 시퀀스 개수: 199692
# 시퀀스 개수: 199693
# 시퀀스 개수: 199694
# 시퀀스 개수: 199695
# 시퀀스 개수: 199696
# 시퀀스 개수: 199697
# 시퀀스 개수: 199698
# 시퀀스 개수: 199699
# 시퀀스 개수: 199700
# 시퀀스 개수: 199701
# 시퀀스 개수: 199702
# 시퀀스 개수: 199703
# 시퀀스 개수: 199704
# 시퀀스 개수: 199705
# 시퀀스 개수: 199706
# 시퀀스 개수: 199707
# 시퀀스 개수: 199708
# 시퀀스 개수: 199709
# 시퀀스 개수: 199710
# 시퀀스 개수: 199711
# 시퀀스 개수: 199712
# 시퀀스 개수: 199713
# 시퀀스 개수: 199714
# 시퀀스 개수: 199715
# 시퀀스 개수: 199716
# 시퀀스 개수: 199717
# 시퀀스 개수: 199718
# 시퀀스 개수: 199719
# 시퀀스 개수: 199720
# 시퀀스 개수: 199721
# 시퀀스 개수: 199722
# 시퀀스 개수: 199723
# 시퀀스 개수: 199724
# 시퀀스 개수: 199725
# 시퀀스 개수: 199726
# 시퀀스 개수: 199727
# 시퀀스 개수: 199728
# 시퀀스 개수: 199729
# 시퀀스 개수: 199730
# 시퀀스 개수: 199731
# 시퀀스 개수: 199732
# 시퀀스 개수: 199733
# 시퀀스 개수: 199734
# 시퀀스 개수: 199735
# 시퀀스 개수: 199736
# 시퀀스 개수: 199737
# 시퀀스 개수: 199738
# 시퀀스 개수: 199739
# 시퀀스 개수: 199740
# 시퀀스 개수: 199741
# 시퀀스 개수: 199742
# 시퀀스 개수: 199743
# 시퀀스 개수: 199744
# 시퀀스 개수: 199745
# 시퀀스 개수: 199746
# 시퀀스 개수: 199747
# 시퀀스 개수: 199748
# 시퀀스 개수: 199749
# 시퀀스 개수: 199750
# 시퀀스 개수: 199751
# 시퀀스 개수: 199752
# 시퀀스 개수: 199753
# 시퀀스 개수: 199754
# 시퀀스 개수: 199755
# 시퀀스 개수: 199756
# 시퀀스 개수: 199757
# 시퀀스 개수: 199758
# 시퀀스 개수: 199759
# 시퀀스 개수: 199760
# 시퀀스 개수: 199761
# 시퀀스 개수: 199762
# 시퀀스 개수: 199763
# 시퀀스 개수: 199764
# 시퀀스 개수: 199765
# 시퀀스 개수: 199766
# 시퀀스 개수: 199767
# 시퀀스 개수: 199768
# 시퀀스 개수: 199769
# 시퀀스 개수: 199770
# 시퀀스 개수: 199771
# 시퀀스 개수: 199772
# 시퀀스 개수: 199773
# 시퀀스 개수: 199774
# 시퀀스 개수: 199775
# 시퀀스 개수: 199776
# 시퀀스 개수: 199777
# 시퀀스 개수: 199778
# 시퀀스 개수: 199779
# 시퀀스 개수: 199780
# 시퀀스 개수: 199781
# 시퀀스 개수: 199782
# 시퀀스 개수: 199783
# 시퀀스 개수: 199784
# 시퀀스 개수: 199785
# 시퀀스 개수: 199786
# 시퀀스 개수: 199787
# 시퀀스 개수: 199788
# 시퀀스 개수: 199789
# 시퀀스 개수: 199790
# 시퀀스 개수: 199791
# 시퀀스 개수: 199792
# 시퀀스 개수: 199793
# 시퀀스 개수: 199794
# 시퀀스 개수: 199795
# 시퀀스 개수: 199796
# 시퀀스 개수: 199797
# 시퀀스 개수: 199798
# 시퀀스 개수: 199799
# 시퀀스 개수: 199800
# 시퀀스 개수: 199801
# 시퀀스 개수: 199802
# 시퀀스 개수: 199803
# 시퀀스 개수: 199804
# 시퀀스 개수: 199805
# 시퀀스 개수: 199806
# 시퀀스 개수: 199807
# 시퀀스 개수: 199808
# 시퀀스 개수: 199809
# 시퀀스 개수: 199810
# 시퀀스 개수: 199811
# 시퀀스 개수: 199812
# 시퀀스 개수: 199813
# 시퀀스 개수: 199814
# 시퀀스 개수: 199815
# 시퀀스 개수: 199816
# 시퀀스 개수: 199817
# 시퀀스 개수: 199818
# 시퀀스 개수: 199819
# 시퀀스 개수: 199820
# 시퀀스 개수: 199821
# 시퀀스 개수: 199822
# 시퀀스 개수: 199823
# 시퀀스 개수: 199824
# 시퀀스 개수: 199825
# 시퀀스 개수: 199826
# 시퀀스 개수: 199827
# 시퀀스 개수: 199828
# 시퀀스 개수: 199829
# 시퀀스 개수: 199830
# 시퀀스 개수: 199831
# 시퀀스 개수: 199832
# 시퀀스 개수: 199833
# 시퀀스 개수: 199834
# 시퀀스 개수: 199835
# 시퀀스 개수: 199836
# 시퀀스 개수: 199837
# 시퀀스 개수: 199838
# 시퀀스 개수: 199839
# 시퀀스 개수: 199840
# 시퀀스 개수: 199841
# 시퀀스 개수: 199842
# 시퀀스 개수: 199843
# 시퀀스 개수: 199844
# 시퀀스 개수: 199845
# 시퀀스 개수: 199846
# 시퀀스 개수: 199847
# 시퀀스 개수: 199848
# 시퀀스 개수: 199849
# 시퀀스 개수: 199850
# 시퀀스 개수: 199851
# 시퀀스 개수: 199852
# 시퀀스 개수: 199853
# 시퀀스 개수: 199854
# 시퀀스 개수: 199855
# 시퀀스 개수: 199856
# 시퀀스 개수: 199857
# 시퀀스 개수: 199858
# 시퀀스 개수: 199859
# 시퀀스 개수: 199860
# 시퀀스 개수: 199861
# 시퀀스 개수: 199862
# 시퀀스 개수: 199863
# 시퀀스 개수: 199864
# 시퀀스 개수: 199865
# 시퀀스 개수: 199866
# 시퀀스 개수: 199867
# 시퀀스 개수: 199868
# 시퀀스 개수: 199869
# 시퀀스 개수: 199870
# 시퀀스 개수: 199871
# 시퀀스 개수: 199872
# 시퀀스 개수: 199873
# 시퀀스 개수: 199874
# 시퀀스 개수: 199875
# 시퀀스 개수: 199876
# 시퀀스 개수: 199877
# 시퀀스 개수: 199878
# 시퀀스 개수: 199879
# 시퀀스 개수: 199880
# 시퀀스 개수: 199881
# 시퀀스 개수: 199882
# 시퀀스 개수: 199883
# 시퀀스 개수: 199884
# 시퀀스 개수: 199885
# 시퀀스 개수: 199886
# 시퀀스 개수: 199887
# 시퀀스 개수: 199888
# 시퀀스 개수: 199889
# 시퀀스 개수: 199890
# 시퀀스 개수: 199891
# 시퀀스 개수: 199892
# 시퀀스 개수: 199893
# 시퀀스 개수: 199894
# 시퀀스 개수: 199895
# 시퀀스 개수: 199896
# 시퀀스 개수: 199897
# 시퀀스 개수: 199898
# 시퀀스 개수: 199899
# 시퀀스 개수: 199900
# 시퀀스 개수: 199901
# 시퀀스 개수: 199902
# 시퀀스 개수: 199903
# 시퀀스 개수: 199904
# 시퀀스 개수: 199905
# 시퀀스 개수: 199906
# 시퀀스 개수: 199907
# 시퀀스 개수: 199908
# 시퀀스 개수: 199909
# 시퀀스 개수: 199910
# 시퀀스 개수: 199911
# 시퀀스 개수: 199912
# 시퀀스 개수: 199913
# 시퀀스 개수: 199914
# 시퀀스 개수: 199915
# 시퀀스 개수: 199916
# 시퀀스 개수: 199917
# 시퀀스 개수: 199918
# 시퀀스 개수: 199919
# 시퀀스 개수: 199920
# 시퀀스 개수: 199921
# 시퀀스 개수: 199922
# 시퀀스 개수: 199923
# 시퀀스 개수: 199924
# 시퀀스 개수: 199925
# 시퀀스 개수: 199926
# 시퀀스 개수: 199927
# 시퀀스 개수: 199928
# 시퀀스 개수: 199929
# 시퀀스 개수: 199930
# 시퀀스 개수: 199931
# 시퀀스 개수: 199932
# 시퀀스 개수: 199933
# 시퀀스 개수: 199934
# 시퀀스 개수: 199935
# 시퀀스 개수: 199936
# 시퀀스 개수: 199937
# 시퀀스 개수: 199938
# 시퀀스 개수: 199939
# 시퀀스 개수: 199940
# 시퀀스 개수: 199941
# 시퀀스 개수: 199942
# 시퀀스 개수: 199943
# 시퀀스 개수: 199944
# 시퀀스 개수: 199945
# 시퀀스 개수: 199946
# 시퀀스 개수: 199947
# 시퀀스 개수: 199948
# 시퀀스 개수: 199949
# 시퀀스 개수: 199950
# 시퀀스 개수: 199951
# 시퀀스 개수: 199952
# 시퀀스 개수: 199953
# 시퀀스 개수: 199954
# 시퀀스 개수: 199955
# 시퀀스 개수: 199956
# 시퀀스 개수: 199957
# 시퀀스 개수: 199958
# 시퀀스 개수: 199959
# 시퀀스 개수: 199960
# 시퀀스 개수: 199961
# 시퀀스 개수: 199962
# 시퀀스 개수: 199963
# 시퀀스 개수: 199964
# 시퀀스 개수: 199965
# 시퀀스 개수: 199966
# 시퀀스 개수: 199967
# 시퀀스 개수: 199968
# 시퀀스 개수: 199969
# 시퀀스 개수: 199970
# 시퀀스 개수: 199971
# 시퀀스 개수: 199972
# 시퀀스 개수: 199973
# 시퀀스 개수: 199974
# 시퀀스 개수: 199975
# 시퀀스 개수: 199976
# 시퀀스 개수: 199977
# 시퀀스 개수: 199978
# 시퀀스 개수: 199979
# 시퀀스 개수: 199980
# 시퀀스 개수: 199981
# 시퀀스 개수: 199982
# 시퀀스 개수: 199983
# 시퀀스 개수: 199984
# 시퀀스 개수: 199985
# 시퀀스 개수: 199986
# 시퀀스 개수: 199987
# 시퀀스 개수: 199988
# 시퀀스 개수: 199989
# 시퀀스 개수: 199990
# 시퀀스 개수: 199991
# 시퀀스 개수: 199992
# 시퀀스 개수: 199993
# 시퀀스 개수: 199994
# 시퀀스 개수: 199995
# 시퀀스 개수: 199996
# 시퀀스 개수: 199997
# 시퀀스 개수: 199998
# 시퀀스 개수: 199999
# 시퀀스 개수: 200000
# 시퀀스 개수: 200001
# 시퀀스 개수: 200002
# 시퀀스 개수: 200003
# 시퀀스 개수: 200004
# 시퀀스 개수: 200005
# 시퀀스 개수: 200006
# 시퀀스 개수: 200007
# 시퀀스 개수: 200008
# 시퀀스 개수: 200009
# 시퀀스 개수: 200010
# 시퀀스 개수: 200011
# 시퀀스 개수: 200012
# 시퀀스 개수: 200013
# 시퀀스 개수: 200014
# 시퀀스 개수: 200015
# 시퀀스 개수: 200016
# 시퀀스 개수: 200017
# 시퀀스 개수: 200018
# 시퀀스 개수: 200019
# 시퀀스 개수: 200020
# 시퀀스 개수: 200021
# 시퀀스 개수: 200022
# 시퀀스 개수: 200023
# 시퀀스 개수: 200024
# 시퀀스 개수: 200025
# 시퀀스 개수: 200026
# 시퀀스 개수: 200027
# 시퀀스 개수: 200028
# 시퀀스 개수: 200029
# 시퀀스 개수: 200030
# 시퀀스 개수: 200031
# 시퀀스 개수: 200032
# 시퀀스 개수: 200033
# 시퀀스 개수: 200034
# 시퀀스 개수: 200035
# 시퀀스 개수: 200036
# 시퀀스 개수: 200037
# 시퀀스 개수: 200038
# 시퀀스 개수: 200039
# 시퀀스 개수: 200040
# 시퀀스 개수: 200041
# 시퀀스 개수: 200042
# 시퀀스 개수: 200043
# 시퀀스 개수: 200044
# 시퀀스 개수: 200045
# 시퀀스 개수: 200046
# 시퀀스 개수: 200047
# 시퀀스 개수: 200048
# 시퀀스 개수: 200049
# 시퀀스 개수: 200050
# 시퀀스 개수: 200051
# 시퀀스 개수: 200052
# 시퀀스 개수: 200053
# 시퀀스 개수: 200054
# 시퀀스 개수: 200055
# 시퀀스 개수: 200056
# 시퀀스 개수: 200057
# 시퀀스 개수: 200058
# 시퀀스 개수: 200059
# 시퀀스 개수: 200060
# 시퀀스 개수: 200061
# 시퀀스 개수: 200062
# 시퀀스 개수: 200063
# 시퀀스 개수: 200064
# 시퀀스 개수: 200065
# 시퀀스 개수: 200066
# 시퀀스 개수: 200067
# 시퀀스 개수: 200068
# 시퀀스 개수: 200069
# 시퀀스 개수: 200070
# 시퀀스 개수: 200071
# 시퀀스 개수: 200072
# 시퀀스 개수: 200073
# 시퀀스 개수: 200074
# 시퀀스 개수: 200075
# 시퀀스 개수: 200076
# 시퀀스 개수: 200077
# 시퀀스 개수: 200078
# 시퀀스 개수: 200079
# 시퀀스 개수: 200080
# 시퀀스 개수: 200081
# 시퀀스 개수: 200082
# 시퀀스 개수: 200083
# 시퀀스 개수: 200084
# 시퀀스 개수: 200085
# 시퀀스 개수: 200086
# 시퀀스 개수: 200087
# 시퀀스 개수: 200088
# 시퀀스 개수: 200089
# 시퀀스 개수: 200090
# 시퀀스 개수: 200091
# 시퀀스 개수: 200092
# 시퀀스 개수: 200093
# 시퀀스 개수: 200094
# 시퀀스 개수: 200095
# 시퀀스 개수: 200096
# 시퀀스 개수: 200097
# 시퀀스 개수: 200098
# 시퀀스 개수: 200099
# 시퀀스 개수: 200100
# 시퀀스 개수: 200101
# 시퀀스 개수: 200102
# 시퀀스 개수: 200103
# 시퀀스 개수: 200104
# 시퀀스 개수: 200105
# 시퀀스 개수: 200106
# 시퀀스 개수: 200107
# 시퀀스 개수: 200108
# 시퀀스 개수: 200109
# 시퀀스 개수: 200110
# 시퀀스 개수: 200111
# 시퀀스 개수: 200112
# 시퀀스 개수: 200113
# 시퀀스 개수: 200114
# 시퀀스 개수: 200115
# 시퀀스 개수: 200116
# 시퀀스 개수: 200117
# 시퀀스 개수: 200118
# 시퀀스 개수: 200119
# 시퀀스 개수: 200120
# 시퀀스 개수: 200121
# 시퀀스 개수: 200122
# 시퀀스 개수: 200123
# 시퀀스 개수: 200124
# 시퀀스 개수: 200125
# 시퀀스 개수: 200126
# 시퀀스 개수: 200127
# 시퀀스 개수: 200128
# 시퀀스 개수: 200129
# 시퀀스 개수: 200130
# 시퀀스 개수: 200131
# 시퀀스 개수: 200132
# 시퀀스 개수: 200133
# 시퀀스 개수: 200134
# 시퀀스 개수: 200135
# 시퀀스 개수: 200136
# 시퀀스 개수: 200137
# 시퀀스 개수: 200138
# 시퀀스 개수: 200139
# 시퀀스 개수: 200140
# 시퀀스 개수: 200141
# 시퀀스 개수: 200142
# 시퀀스 개수: 200143
# 시퀀스 개수: 200144
# 시퀀스 개수: 200145
# 시퀀스 개수: 200146
# 시퀀스 개수: 200147
# 시퀀스 개수: 200148
# 시퀀스 개수: 200149
# 시퀀스 개수: 200150
# 시퀀스 개수: 200151
# 시퀀스 개수: 200152
# 시퀀스 개수: 200153
# 시퀀스 개수: 200154
# 시퀀스 개수: 200155
# 시퀀스 개수: 200156
# 시퀀스 개수: 200157
# 시퀀스 개수: 200158
# 시퀀스 개수: 200159
# 시퀀스 개수: 200160
# 시퀀스 개수: 200161
# 시퀀스 개수: 200162
# 시퀀스 개수: 200163
# 시퀀스 개수: 200164
# 시퀀스 개수: 200165
# 시퀀스 개수: 200166
# 시퀀스 개수: 200167
# 시퀀스 개수: 200168
# 시퀀스 개수: 200169
# 시퀀스 개수: 200170
# 시퀀스 개수: 200171
# 시퀀스 개수: 200172
# 시퀀스 개수: 200173
# 시퀀스 개수: 200174
# 시퀀스 개수: 200175
# 시퀀스 개수: 200176
# 시퀀스 개수: 200177
# 시퀀스 개수: 200178
# 시퀀스 개수: 200179
# 시퀀스 개수: 200180
# 시퀀스 개수: 200181
# 시퀀스 개수: 200182
# 시퀀스 개수: 200183
# 시퀀스 개수: 200184
# 시퀀스 개수: 200185
# 시퀀스 개수: 200186
# 시퀀스 개수: 200187
# 시퀀스 개수: 200188
# 시퀀스 개수: 200189
# 시퀀스 개수: 200190
# 시퀀스 개수: 200191
# 시퀀스 개수: 200192
# 시퀀스 개수: 200193
# 시퀀스 개수: 200194
# 시퀀스 개수: 200195
# 시퀀스 개수: 200196
# 시퀀스 개수: 200197
# 시퀀스 개수: 200198
# 시퀀스 개수: 200199
# 시퀀스 개수: 200200
# 시퀀스 개수: 200201
# 시퀀스 개수: 200202
# 시퀀스 개수: 200203
# 시퀀스 개수: 200204
# 시퀀스 개수: 200205
# 시퀀스 개수: 200206
# 시퀀스 개수: 200207
# 시퀀스 개수: 200208
# 시퀀스 개수: 200209
# 시퀀스 개수: 200210
# 시퀀스 개수: 200211
# 시퀀스 개수: 200212
# 시퀀스 개수: 200213
# 시퀀스 개수: 200214
# 시퀀스 개수: 200215
# 시퀀스 개수: 200216
# 시퀀스 개수: 200217
# 시퀀스 개수: 200218
# 시퀀스 개수: 200219
# 시퀀스 개수: 200220
# 시퀀스 개수: 200221
# 시퀀스 개수: 200222
# 시퀀스 개수: 200223
# 시퀀스 개수: 200224
# 시퀀스 개수: 200225
# 시퀀스 개수: 200226
# 시퀀스 개수: 200227
# 시퀀스 개수: 200228
# 시퀀스 개수: 200229
# 시퀀스 개수: 200230
# 시퀀스 개수: 200231
# 시퀀스 개수: 200232
# 시퀀스 개수: 200233
# 시퀀스 개수: 200234
# 시퀀스 개수: 200235
# 시퀀스 개수: 200236
# 시퀀스 개수: 200237
# 시퀀스 개수: 200238
# 시퀀스 개수: 200239
# 시퀀스 개수: 200240
# 시퀀스 개수: 200241
# 시퀀스 개수: 200242
# 시퀀스 개수: 200243
# 시퀀스 개수: 200244
# 시퀀스 개수: 200245
# 시퀀스 개수: 200246
# 시퀀스 개수: 200247
# 시퀀스 개수: 200248
# 시퀀스 개수: 200249
# 시퀀스 개수: 200250
# 시퀀스 개수: 200251
# 시퀀스 개수: 200252
# 시퀀스 개수: 200253
# 시퀀스 개수: 200254
# 시퀀스 개수: 200255
# 시퀀스 개수: 200256
# 시퀀스 개수: 200257
# 시퀀스 개수: 200258
# 시퀀스 개수: 200259
# 시퀀스 개수: 200260
# 시퀀스 개수: 200261
# 시퀀스 개수: 200262
# 시퀀스 개수: 200263
# 시퀀스 개수: 200264
# 시퀀스 개수: 200265
# 시퀀스 개수: 200266
# 시퀀스 개수: 200267
# 시퀀스 개수: 200268
# 시퀀스 개수: 200269
# 시퀀스 개수: 200270
# 시퀀스 개수: 200271
# 시퀀스 개수: 200272
# 시퀀스 개수: 200273
# 시퀀스 개수: 200274
# 시퀀스 개수: 200275
# 시퀀스 개수: 200276
# 시퀀스 개수: 200277
# 시퀀스 개수: 200278

# %% [markdown]
# ## 말뭉치에서 고유한 글자를 담은 리스트 처리

# %%
chars = sorted(list(set(text)))
print('고유한 글자:', len(chars))
# Out:
# 고유한 글자: 57

# %% [markdown]
# ## chars 리스트에 있는 글자와 글자의 인덱스를 매핑한 딕셔너리

# %%
char_indices = dict((char, chars.index(char)) for char in chars)

print('벡터화...')
# Out:
# 벡터화...

# %% [markdown]
# ## 글자를 원-핫 인코딩하여 0과 1의 이진 배열로 변경

# %%
x = np.zeros((len(sentences), maxlen, len(chars)),dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
   for t,char in enumerate(sentence):
       x[i, t, char_indices[char]] = 1
   y[i, char_indices[next_chars[i]]] = 1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %% [markdown]
# ## 네트워크 구성

# %%
from tensorflow.keras import layers,models

model = models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
from tensorflow.keras import optimizers

optimizer = optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/rmsprop.py:130: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %% [markdown]
# ## 언어 모델 훈련과 샘플링
#
# 훈련된 모델과 시드로 쓰일 간단한 텍스트가 주어지면 다음과 같이 반복하여 새로운 텍스트를 생성할 수 있습니다.
#
# 1.	지금까지 생성된 텍스트를 주입하여 모델에서 다음 글자에 대한 확률 분포를 뽑습니다.
# 2.	특정 온도로 이 확률 분포의 가중치를 조정합니다.
# 3.	가중치가 조정된 분포에서 무작위로 새로운 글자를 샘플링합니다.
# 4.	새로운 글자를 생성된 텍스트의 끝에 추가합니다.
#
# 다음 코드는 모델에서 나온 원본 확률 분포의 가중치를 조정하고 새로운 글자의 인덱스를 추출합니다(샘플링 함수입니다):

# %% [markdown]
# 밑이 자연상수 e인 지수함수(e^x)의 그래프<br>
# https://wooono.tistory.com/214
#
# Python Numpy.log()-로그 <br>
# https://www.delftstack.com/ko/api/numpy/python-numpy-log/

# %%
def sample(preds, temperature=1.0):
  preds = np.asarray(preds).astype('float64')
  preds = np.log(preds) / temperature
  exp_preds = np.exp(preds)
  preds = exp_preds / np.sum(exp_preds)
  probas = np.random.multinomial(1, preds, 1)
  return np.argmax(probas)

# %% [markdown]
# [과제] 텍스트를 생성한 후 temperature에 따라 생성된 text가 어떻게 다른지 비교하세요

# %%
import random
import sys

random.seed(42)
# 데이터에서 한 번만 반복해서 모델을 학습합니다.
start_index = random.randint(0, len(text) - maxlen - 1)

for epoch in range(1, 60):
     print('에포크',epoch)
model.fit(x,y, batch_size=128, epochs=1)

# 무작위로 시드 텍스트를 선택합니다
seed_text = text[start_index : start_index + maxlen]
print('--- 시드 텍스트:' +seed_text + '"')

# 여러가지 샘플링 온도를 시도합니다.
for temperature in [0.2,0.5,1.0,1.2]:
  print('---- 온도:',temperature)
  generated_text = seed_text
  sys.stdout.write(generated_text)

  for i in range(400):
    sampled = np.zeros((1,maxlen, len(chars)))
    for t, char in enumerate(generated_text):
      sampled[0, t, char_indices[char]] = 1.

    preds = model.predict(sampled, verbose=0)[0]
    next_index = sample(preds, temperature)
    next_char = chars[next_index]
    
    generated_text += next_char
    generated_text = generated_text[1:]

    sys.stdout.write(next_char)
    sys.stdout.flush()
  print()
# Out:
# 에포크 1
# 에포크 2
# 에포크 3
# 에포크 4
# 에포크 5
# 에포크 6
# 에포크 7
# 에포크 8
# 에포크 9
# 에포크 10
# 에포크 11
# 에포크 12
# 에포크 13
# 에포크 14
# 에포크 15
# 에포크 16
# 에포크 17
# 에포크 18
# 에포크 19
# 에포크 20
# 에포크 21
# 에포크 22
# 에포크 23
# 에포크 24
# 에포크 25
# 에포크 26
# 에포크 27
# 에포크 28
# 에포크 29
# 에포크 30
# 에포크 31
# 에포크 32
# 에포크 33
# 에포크 34
# 에포크 35
# 에포크 36
# 에포크 37
# 에포크 38
# 에포크 39
# 에포크 40
# 에포크 41
# 에포크 42
# 에포크 43
# 에포크 44
# 에포크 45
# 에포크 46
# 에포크 47
# 에포크 48
# 에포크 49
# 에포크 50
# 에포크 51
# 에포크 52
# 에포크 53
# 에포크 54
# 에포크 55
# 에포크 56
# 에포크 57
# 에포크 58
# 에포크 59
# 1565/1565 [==============================] - 166s 103ms/step - loss: 1.9753
# --- 시드 텍스트:the slowly ascending ranks and classes, in which,
# through fo"
# ---- 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the strong and the strong to the strong the strong the specially the strong of the strong the strong the man in the strong and the indeed to the stranger and should the strong the greated in the realy the strong the greated the strong to the sting the strong the consection of the strong the still to the strong the strong the strong the strong the strong the strong the complase of the strong the
# ---- 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the consectity of is and special to hable us one a "accausting on the flough the such the place the sesse of hele of the man and any one man and the science of the clace of the strong the stands of the strong he the will to must and strong as out of the strength and pase is some has before of the same that is any all the caush of mankerent and more consequenting under the grouther the stands of
# ---- 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for this merning henough of churt gever mase bact intell the eproblioleb: dis a althou aprevy? he ges omfonity of the duen of dreary ome me the minct. he was, in owhy man, they conlese of chlmould aey of
# heme be paris mugan as intend with he who hell
# indibking aloun ascass bost albifage lare and undow st plact mankind myself--all
# the
# condettment the ? difcerting of lyares as dour get, philosophy, ha
# ---- 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fore logen ro sty ceayy
# 12buous emplensly grofans donest misitobiningminssspect,
# the form his poiseld cogen and loftionate he drem. it generable hid folsible inceneration of which bruchaile insidet, foosidirg
#  futurliem is hell as
# not of "casimitits we happencedly, predevery roble onrely pythein! in th[riges, ha sove theo cirnancl bat mater sas ut faist in ights
#
# sy
# "recemfant
# it, precosrivines and
